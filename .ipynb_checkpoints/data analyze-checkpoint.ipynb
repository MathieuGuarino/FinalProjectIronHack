# %% [markdown]
# # Data Analyze
# ## Daily Happiness & Employee Turnover

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
from sklearn import preprocessing
import numpy as np
from scipy.stats import linregress
import datetime as dt

# %%
churn = pd.read_csv('churn.csv')
commentInteractions = pd.read_csv('commentInteractions.csv')
votes = pd.read_csv('votes.csv')
comments_clean_anonimized = pd.read_csv('comments_clean_anonimized.csv')
# Out:
# /home/osboxes/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # 1.1 Last participation date of employees
#
# ## The lastParticipationExists.csv file contains information about the date of the last interaction of an employee with the app.
#
#     employee: An integer id that identifies an amployee inside a company. (negative = not in the company anymore)
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#     numVotes: Total number of happyness votes emited by the user.
#     lastParticipationDate: Date of the last interaction of the user with the app.
#     stillExists: Boolean that is True if the user is still registered in the app.

# %%
churn['uid'] = churn.employee.apply(str) + churn.companyAlias

# out_employees = churn[churn.employee < 0]
# Out:
#       employee              companyAlias  numVotes  \
# 1           -2  56aec740f1ef260003e307d6         0
# 5           -4  56aec740f1ef260003e307d6         0
# 11          -6  56aec740f1ef260003e307d6         0
# 359         -3  54d43612e4b0f6a40755d93e         0
# 379         -3  5370af43e4b0cff95558c12a         0
# ...        ...                       ...       ...
# 4493       -49  58a728a0e75bda00042a3468         0
# 4494       -50  58a728a0e75bda00042a3468         0
# 4496       -51  58a728a0e75bda00042a3468         0
# 4498       -52  58a728a0e75bda00042a3468         0
# 4500       -53  58a728a0e75bda00042a3468         0
#
#               lastParticipationDate  stillExists                          uid
# 1      Wed Jan 18 14:00:55 CET 2017        False   -256aec740f1ef260003e307d6
# 5      Mon Nov 07 17:41:56 CET 2016        False   -456aec740f1ef260003e307d6
# 11    Tue Oct 25 17:17:21 CEST 2016        False   -656aec740f1ef260003e307d6
# 359   Thu May 26 09:57:28 CEST 2016        False   -354d43612e4b0f6a40755d93e
# 379    Mon Jan 23 18:11:02 CET 2017        False   -35370af43e4b0cff95558c12a
# ...                             ...          ...                          ...
# 4493   Thu Feb 23 11:25:32 CET 2017        False  -4958a728a0e75bda00042a3468
# 4494   Thu Feb 23 10:32:58 CET 2017        False  -5058a728a0e75bda00042a3468
# 4496   Wed Feb 22 14:20:27 CET 2017        False  -5158a728a0e75bda00042a3468
# 4498   Wed Feb 22 13:54:47 CET 2017        False  -5258a728a0e75bda00042a3468
# 4500   Wed Feb 22 13:50:57 CET 2017        False  -5358a728a0e75bda00042a3468
#
# [429 rows x 6 columns]

# %%
# remove negative users, there seems to have no activities for these users
# churn = churn[churn.employee > 0]
# remove employee with 0 or 1 votes, minority
# churn = churn[churn.numVotes > 1]

churn = churn.drop_duplicates()
churn.sample()
# Out:
#       employee              companyAlias  numVotes  \
# 2502         5  57d979b72a040a00036a8925        11
#
#              lastParticipationDate  stillExists                        uid
# 2502  Wed Feb 01 12:16:03 CET 2017         True  557d979b72a040a00036a8925

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3944 entries, 0 to 4845
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3944 non-null   int64
#  1   companyAlias           3944 non-null   object
#  2   numVotes               3944 non-null   int64
#  3   lastParticipationDate  3944 non-null   object
#  4   stillExists            3944 non-null   bool
#  5   uid                    3944 non-null   object
# dtypes: bool(1), int64(2), object(3)
# memory usage: 188.7+ KB

# %%
plt.figure(figsize=(20,8)) 
churn.numVotes.hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3944 entries, 0 to 4845
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3944 non-null   int64
#  1   companyAlias           3944 non-null   object
#  2   numVotes               3944 non-null   int64
#  3   lastParticipationDate  3944 non-null   object
#  4   stillExists            3944 non-null   bool
#  5   uid                    3944 non-null   object
# dtypes: bool(1), int64(2), object(3)
# memory usage: 188.7+ KB

# %%
churn.lastParticipationDate = pd.to_datetime(churn.lastParticipationDate)
#pd.to_datetime(churn.lastParticipationDate).apply(lambda x: x.toordinal())

# %%
churn_2016 = churn[(churn['lastParticipationDate'] >= '2016-01-01') & (churn['lastParticipationDate'] < '2017-01-01')]

# %%
churn.lastParticipationDate.describe()
# Out:
# count                             3944
# unique                            1308
# top       Mon Mar 20 01:00:00 CET 2017
# freq                               477
# Name: lastParticipationDate, dtype: object

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3944 entries, 0 to 4845
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3944 non-null   int64
#  1   companyAlias           3944 non-null   object
#  2   numVotes               3944 non-null   int64
#  3   lastParticipationDate  3944 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            3944 non-null   bool
#  5   uid                    3944 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 188.7+ KB

# %%
fig, ax = plt.subplots(figsize=(13,13))
sns.lineplot(data=churn_2016, x="lastParticipationDate", y="numVotes")
# Out:
# <AxesSubplot:xlabel='lastParticipationDate', ylabel='numVotes'>

# %%
sns.countplot(x="stillExists", data=churn)
# Out:
# <AxesSubplot:xlabel='stillExists', ylabel='count'>

# %%
employee_still_exists = churn[(churn.stillExists == True) & (churn.employee > 0)]
employee_still_exists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3312 entries, 0 to 4845
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3312 non-null   int64
#  1   companyAlias           3312 non-null   object
#  2   numVotes               3312 non-null   int64
#  3   lastParticipationDate  3312 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            3312 non-null   bool
#  5   uid                    3312 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 158.5+ KB

# %%
employee_still_exists.numVotes.mean()
# Out:
# 57.83967391304348

# %%
employee_doesnot_exists = churn[(churn.stillExists == False) & (churn.employee > 0)]
employee_doesnot_exists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 632 entries, 3 to 4730
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               632 non-null    int64
#  1   companyAlias           632 non-null    object
#  2   numVotes               632 non-null    int64
#  3   lastParticipationDate  632 non-null    datetime64[ns, tzlocal()]
#  4   stillExists            632 non-null    bool
#  5   uid                    632 non-null    object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 30.2+ KB

# %%
employee_doesnot_exists.numVotes.mean()
# Out:
# 48.15981012658228

# %%
employee_doesnot_exists.numVotes.hist()
# Out:
# <AxesSubplot:>

# %%
employee_still_exists.numVotes.hist()
# Out:
# <AxesSubplot:>

# %%
to_transform = churn.groupby('companyAlias').mean().drop('employee', axis=1)
to_transform.head()
# Out:
#                            numVotes  stillExists
# companyAlias
# 5370af43e4b0cff95558c12a  31.267327     0.237624
# 53a2dd43e4b01cc02f1e9011  36.162791     0.945736
# 5474b9cde4b0bf7614b2c66f   5.500000     1.000000
# 54d43612e4b0f6a40755d93e  26.000000     0.647059
# 54e52607e4b01191dc064966  97.523810     0.521905

# %%
# à gérêr plus tard
x = to_transform[['numVotes']].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

# %%
#df['stillExists'] = churn.stillExists.astype(int)
df['stillExists'] = to_transform.stillExists.values

# %%
df['companyAlias'] = to_transform.reset_index().companyAlias

# %%
df.columns = ['numVotes','stillExists','companyAlias']

# %%
sns.scatterplot(data=df, x="numVotes", y="stillExists")
# Out:
# <AxesSubplot:xlabel='numVotes', ylabel='stillExists'>

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3944 entries, 0 to 4845
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3944 non-null   int64
#  1   companyAlias           3944 non-null   object
#  2   numVotes               3944 non-null   int64
#  3   lastParticipationDate  3944 non-null   object
#  4   stillExists            3944 non-null   bool
#  5   uid                    3944 non-null   object
# dtypes: bool(1), int64(2), object(3)
# memory usage: 188.7+ KB

# %%
personnes_absentes = churn[churn.stillExists == False].uid

# %%
churn.describe()
# Out:
#           employee     numVotes
# count  3944.000000  3944.000000
# mean    191.365112    56.288540
# std     198.671312    75.288819
# min       1.000000     2.000000
# 25%      52.000000     8.000000
# 50%     135.000000    24.000000
# 75%     249.000000    75.000000
# max     999.000000   740.000000

# %%
employee_still_exists
# Out:
#       employee              companyAlias  numVotes     lastParticipationDate  \
# 0          512  56aec740f1ef260003e307d6         4 2017-02-23 12:48:04+01:00
# 2            2  56aec740f1ef260003e307d6        72 2017-03-17 01:00:00+01:00
# 4            3  56aec740f1ef260003e307d6        22 2017-02-16 01:00:00+01:00
# 6            4  56aec740f1ef260003e307d6       195 2017-03-20 01:00:00+01:00
# 7          516  56aec740f1ef260003e307d6        29 2017-03-20 12:28:45+01:00
# ...        ...                       ...       ...                       ...
# 4836       851  58a728a0e75bda00042a3468         3 2017-03-17 10:43:59+01:00
# 4837       852  58a728a0e75bda00042a3468         5 2017-03-19 12:27:18+01:00
# 4838       853  58a728a0e75bda00042a3468         2 2017-03-17 01:00:00+01:00
# 4839       854  58a728a0e75bda00042a3468         3 2017-03-20 17:11:14+01:00
# 4845        17  573a0671b5ec330003add34a         7 2016-06-28 02:00:00+02:00
#
#       stillExists                          uid
# 0            True  51256aec740f1ef260003e307d6
# 2            True    256aec740f1ef260003e307d6
# 4            True    356aec740f1ef260003e307d6
# 6            True    456aec740f1ef260003e307d6
# 7            True  51656aec740f1ef260003e307d6
# ...           ...                          ...
# 4836         True  85158a728a0e75bda00042a3468
# 4837         True  85258a728a0e75bda00042a3468
# 4838         True  85358a728a0e75bda00042a3468
# 4839         True  85458a728a0e75bda00042a3468
# 4845         True   17573a0671b5ec330003add34a
#
# [3312 rows x 6 columns]

# %% [markdown]
# # 1.2 Employee Interactions
#
# ## The file commentInteractions.csv contains information about which employee liked or disliked a given comment.
#
#     employee: An integer id that identifies an amployee inside a company.
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#
#     commentId: A unique id for a given comment that allows us to relate it with the comments in anon_comments.csv.
#
#     liked: A boolean that is True if the employee liked the comment.
#     disliked: A boolean that is True if the employee disliked the comment.

# %%
commentInteractions
# Out:
#         employee              companyAlias liked disliked  \
# 0            307  56aec740f1ef260003e307d6  True    False
# 1             36  56aec740f1ef260003e307d6  True    False
# 2            276  56aec740f1ef260003e307d6  True    False
# 3             24  56aec740f1ef260003e307d6  True    False
# 4            382  56aec740f1ef260003e307d6  True    False
# ...          ...                       ...   ...      ...
# 336955       -49  58a728a0e75bda00042a3468  True    False
# 336956       232  58a728a0e75bda00042a3468  True    False
# 336957       -25  58a728a0e75bda00042a3468  True    False
# 336958        36  58a728a0e75bda00042a3468  True    False
# 336959       -47                   58a728a   NaN      NaN
#
#                        commentId
# 0       58d018d7e010990004e38070
# 1       58d018d7e010990004e38070
# 2       58d018d7e010990004e38070
# 3       58d018d7e010990004e38070
# 4       58d0179ae010990004e3806d
# ...                          ...
# 336955  58ad8adeb8242400048bf834
# 336956  58ad8adeb8242400048bf834
# 336957  58ad8adeb8242400048bf834
# 336958  58ad8adeb8242400048bf834
# 336959                       NaN
#
# [336960 rows x 5 columns]

# %%
commentInteractions[commentInteractions.employee < 0]
# Out:
#         employee              companyAlias  liked disliked  \
# 8385          -2  56aec740f1ef260003e307d6   True    False
# 8420          -2  56aec740f1ef260003e307d6   True    False
# 8492          -2  56aec740f1ef260003e307d6   True    False
# 21444         -4  56aec740f1ef260003e307d6  False     True
# 21699         -6  56aec740f1ef260003e307d6   True    False
# ...          ...                       ...    ...      ...
# 336940       -13  58a728a0e75bda00042a3468   True    False
# 336950       -10  58a728a0e75bda00042a3468   True    False
# 336955       -49  58a728a0e75bda00042a3468   True    False
# 336957       -25  58a728a0e75bda00042a3468   True    False
# 336959       -47                   58a728a    NaN      NaN
#
#                        commentId
# 8385    587f674be6b4fd00049bcfef
# 8420    587f4557e6b4fd00049bcfce
# 8492    587f1897e6b4fd00049bcfae
# 21444   5810da7b06f4880003f9f4a7
# 21699   580f77bf3443620003f46916
# ...                          ...
# 336940  58ad899db8242400048bf830
# 336950  58ad8adeb8242400048bf834
# 336955  58ad8adeb8242400048bf834
# 336957  58ad8adeb8242400048bf834
# 336959                       NaN
#
# [12482 rows x 5 columns]

# %%
out_employees.sample()
# Out:
#       employee              companyAlias  numVotes  \
# 1564       -49  54e52607e4b01191dc064966         0
#
#              lastParticipationDate  stillExists                          uid
# 1564  Thu Mar 02 09:59:38 CET 2017        False  -4954e52607e4b01191dc064966

# %%
commentInteractions['uid'] = commentInteractions.employee.apply(str) + commentInteractions.companyAlias

# %%
# commentInteractions = commentInteractions[commentInteractions.employee > 0]
commentInteractions = commentInteractions.drop_duplicates()
# Out:
# <ipython-input-144-28dac2d79c45>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commentInteractions['uid'] = commentInteractions.employee.apply(str) + commentInteractions.companyAlias

# %%
commentInteractions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336960 entries, 0 to 336959
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   employee      336960 non-null  int64
#  1   companyAlias  336960 non-null  object
#  2   liked         336959 non-null  object
#  3   disliked      336959 non-null  object
#  4   commentId     336959 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 12.9+ MB

# %%
commentInteractions.groupby('uid').sum().drop_duplicates()
# Out:
#                               employee
# uid
# -1015370af43e4b0cff95558c12a      -101
# -1025370af43e4b0cff95558c12a      -102
# -1035370af43e4b0cff95558c12a      -618
# -10354e52607e4b01191dc064966      -721
# -1045370af43e4b0cff95558c12a      -104
# ...                                ...
# 9954e52607e4b01191dc064966        8118
# 9956aec740f1ef260003e307d6         990
# 99574c5ade56b6300003009965        3366
# 9957bb2f0b3bae540003a8d453        5247
# 99654e52607e4b01191dc064966      21912
#
# [2674 rows x 1 columns]

# %%
commentInteractions = commentInteractions.dropna() #we only have one na row

# %%
commentInteractions.liked.sum() / commentInteractions.shape[0]
# Out:
# 0.8436963549901224

# %%
commentInteractions.disliked.sum() / commentInteractions.shape[0]
# Out:
# 0.15630364500987762

# %%
commentInteractions.liked = commentInteractions.liked.astype(int)
commentInteractions.disliked = commentInteractions.disliked.astype(int)

# %%
commentInteractions_grouped = commentInteractions.groupby('companyAlias').mean().drop('employee', axis = 1).reset_index()

# %%
sorted_commentInteractions = commentInteractions_grouped.sort_values(by=['liked'])

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(data=commentInteractions_grouped, x='liked', y='companyAlias', legend=False)
# Out:
# <AxesSubplot:xlabel='liked', ylabel='companyAlias'>

# %%
fig, ax = plt.subplots(figsize=(13,13))
ax = sns.barplot(data=sorted_commentInteractions, x='liked', y='companyAlias')
#ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
commentInteractions.describe()
# Out:
#             employee          liked       disliked
# count  324471.000000  324471.000000  324471.000000
# mean      172.173411       0.843696       0.156304
# std       178.699301       0.363144       0.363144
# min         1.000000       0.000000       0.000000
# 25%        45.000000       1.000000       0.000000
# 50%       128.000000       1.000000       0.000000
# 75%       214.000000       1.000000       0.000000
# max       999.000000       1.000000       1.000000

# %%
commentInteractions.sample()
# Out:
#         employee              companyAlias  liked  disliked  \
# 176394         9  5641f96713664c000332c8cd      1         0
#
#                        commentId                        uid
# 176394  58553a5afb14780004332637  95641f96713664c000332c8cd

# %% [markdown]
# # 1.3 Happyness votes data
#
# ## The data regarding the votes of the app users is stored in votes.csv. This file containg 4 different columns:
#
#     employee: An integer id that identifies an amployee inside a company.
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#     voteDate: String representing the date a given vote was emited.
#     vote: The numeric value of the vote emited ranging from 1 to 4.

# %%
votes
# Out:
#         employee              companyAlias                       voteDate  \
# 0             31  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 1             33  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 2             79  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 3             94  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 4             16  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# ...          ...                       ...                            ...
# 221227        17  573a0671b5ec330003add34a  Fri Jun 03 02:00:00 CEST 2016
# 221228        17  573a0671b5ec330003add34a  Tue Jun 07 02:00:00 CEST 2016
# 221229        17  573a0671b5ec330003add34a  Mon Jun 13 02:00:00 CEST 2016
# 221230        17  573a0671b5ec330003add34a  Tue Jun 28 02:00:00 CEST 2016
# 221231        19  573a0671b5ec330003add34a  Mon Jul 04 02:00:00 CEST 2016
#
#         vote
# 0          4
# 1          4
# 2          4
# 3          4
# 4          2
# ...      ...
# 221227     3
# 221228     4
# 221229     4
# 221230     4
# 221231     4
#
# [221232 rows x 4 columns]

# %%
votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221232 entries, 0 to 221231
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   employee      221232 non-null  int64
#  1   companyAlias  221232 non-null  object
#  2   voteDate      221232 non-null  object
#  3   vote          221232 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 6.8+ MB

# %%
votes.voteDate = pd.to_datetime(votes.voteDate)

# %%
# votes = votes[votes.employee > 0]
votes['uid'] = votes.employee.apply(str) + votes.companyAlias
votes = votes.drop_duplicates()

# %%
votes.head()
# Out:
#    employee              companyAlias                  voteDate  vote  \
# 0        31  56aec740f1ef260003e307d6 2016-02-01 01:00:00+01:00     4
# 1        33  56aec740f1ef260003e307d6 2016-02-01 01:00:00+01:00     4
# 2        79  56aec740f1ef260003e307d6 2016-02-01 01:00:00+01:00     4
# 3        94  56aec740f1ef260003e307d6 2016-02-01 01:00:00+01:00     4
# 4        16  56aec740f1ef260003e307d6 2016-02-01 01:00:00+01:00     2
#
#                           uid
# 0  3156aec740f1ef260003e307d6
# 1  3356aec740f1ef260003e307d6
# 2  7956aec740f1ef260003e307d6
# 3  9456aec740f1ef260003e307d6
# 4  1656aec740f1ef260003e307d6

# %%
votes.voteDate = votes.voteDate.map(dt.datetime.toordinal)

# %%
votes[votes.uid == '1656aec740f1ef260003e307d6'].vote.values
# Out:
# array([2, 3, 2, 2, 4, 3, 1, 1, 1, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 2, 4, 4, 4, 2, 1, 1, 4, 1, 1, 1, 4,
#        4, 1])

# %%
votes[votes.uid == '1656aec740f1ef260003e307d6'].voteDate.values
# Out:
# array([735995, 735999, 736003, 736004, 736009, 736010, 736011, 736017,
#        736018, 736019, 736020, 736025, 736026, 736027, 736032, 736033,
#        736038, 736039, 736040, 736041, 736044, 736053, 736054, 736055,
#        736058, 736059, 736060, 736061, 736066, 736068, 736069, 736072,
#        736073, 736074, 736075, 736076, 736087, 736090, 736093, 736094,
#        736095, 736096, 736097, 736100, 736101, 736102, 736104, 736107,
#        736109, 736111, 736114, 736116, 736117, 736118, 736123, 736128,
#        736131, 736132, 736136, 736137, 736143, 736144, 736149, 736150,
#        736151, 736153, 736156, 736158, 736160, 736164, 736165, 736174,
#        736184, 736214, 736215, 736219, 736220, 736234, 736235, 736247,
#        736254, 736264, 736271, 736284, 736289, 736291, 736300, 736305,
#        736345, 736376])

# %%
votes.uid.unique()
# Out:
# array(['3156aec740f1ef260003e307d6', '3356aec740f1ef260003e307d6',
#        '7956aec740f1ef260003e307d6', ..., '85958a728a0e75bda00042a3468',
#        '17573a0671b5ec330003add34a', '19573a0671b5ec330003add34a'],
#       dtype=object)

# %%
def calculate_time_between_votes(df):
    users = votes.uid.unique()
    totals = []
    for user in users:
        votes_by_id = df[df.uid == user].voteDate.values
        total = 0
        for index in range(len(votes_by_id)-1):
            total += votes_by_id[index+1]-votes_by_id[index]
        totals.append(total)
    return totals

# %%
activities = calculate_time_between_votes(votes)

# %%
len(activities)
# Out:
# 4377

# %%
votes_grouped_by_user = votes.groupby('uid').mean().drop('employee', axis = 1)

# %%
def calculate_slopes_over_time(df):
    slopes = []
    users = df.uid.unique()
    for user in users:
        y = df[df.uid == user].vote.values
        len_y = len(y)
        x = df[df.uid == user].voteDate.values
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        slopes.append(slope)
    return slopes

slopes = calculate_slopes_over_time(votes)
# Out:
# /home/osboxes/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /home/osboxes/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:140: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /home/osboxes/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:142: RuntimeWarning: invalid value encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %%
# we negate the slopes because the data is from the latest to the oldest
mynegslopes = [ -x for x in slopes]

# %%
df_happy = pd.DataFrame(list(zip(mynegslopes, votes.uid.unique())),
               columns =['Happiness', 'uid'])
df_happy = df_happy.fillna(0)

# %%
votes_grouped_by_user
# Out:
#                                   voteDate      vote
# uid
# 10053a2dd43e4b01cc02f1e9011  736170.821862  1.004049
# 10054e52607e4b01191dc064966  735980.514793  2.213018
# 1005641f96713664c000332c8cd  736187.617647  2.137255
# 10056aec740f1ef260003e307d6  736292.310160  4.000000
# 10056e2a905e3b6fe0003e32855  736236.000000  3.750000
# ...                                    ...       ...
# 995809cc9eff2ea40003fda44d   736383.000000  3.000000
# 99581b08041a0ef8000308aef6   736338.363636  3.854545
# 99654e52607e4b01191dc064966  736289.500000  2.450000
# 99754e52607e4b01191dc064966  736282.000000  3.000000
# 99954e52607e4b01191dc064966  736291.050000  2.850000
#
# [4377 rows x 2 columns]

# %%
df_activity = pd.DataFrame(list(zip(activities, votes.uid.unique())),
               columns =['Activity', 'uid'])
df_activity = df_activity.fillna(0)

# %%
votes_grouped_by_user_with_happy = votes_grouped_by_user.merge(df_happy, left_on='uid', right_on='uid')

# %%
votes_grouped_by_user_with_happy = votes_grouped_by_user_with_happy.merge(df_activity, left_on='uid', right_on='uid')

# %%
votes_grouped_by_user_with_happy
# Out:
#                               uid       voteDate      vote  Happiness  \
# 0     10053a2dd43e4b01cc02f1e9011  736170.821862  1.004049   0.000099
# 1     10054e52607e4b01191dc064966  735980.514793  2.213018   0.000101
# 2     1005641f96713664c000332c8cd  736187.617647  2.137255   0.018121
# 3     10056aec740f1ef260003e307d6  736292.310160  4.000000  -0.000000
# 4     10056e2a905e3b6fe0003e32855  736236.000000  3.750000  -0.142857
# ...                           ...            ...       ...        ...
# 4372   995809cc9eff2ea40003fda44d  736383.000000  3.000000   0.000000
# 4373   99581b08041a0ef8000308aef6  736338.363636  3.854545  -0.005784
# 4374  99654e52607e4b01191dc064966  736289.500000  2.450000  -0.008205
# 4375  99754e52607e4b01191dc064966  736282.000000  3.000000   0.000000
# 4376  99954e52607e4b01191dc064966  736291.050000  2.850000  -0.000456
#
#       Activity
# 0          254
# 1          746
# 2          140
# 3          276
# 4            5
# ...        ...
# 4372         0
# 4373        92
# 4374       191
# 4375         0
# 4376       164
#
# [4377 rows x 5 columns]

# %%
votes_grouped_by_user_with_happy.isna().sum()
# Out:
# uid          0
# voteDate     0
# vote         0
# Happiness    0
# Activity     0
# dtype: int64

# %%
# group to analyze date with unique employees and not duplicates
votes_grouped = votes.groupby(['employee','companyAlias']).mean()

# %%
votes_grouped
# Out:
#                                         voteDate      vote
# employee companyAlias
# 1        5474b9cde4b0bf7614b2c66f  735562.500000  4.000000
#          54d43612e4b0f6a40755d93e  735955.562500  3.125000
#          54e52607e4b01191dc064966  736009.029851  2.985075
#          5641f96713664c000332c8cd  736252.821012  3.171206
#          56558cfd07a5de00030908fb  735929.000000  3.500000
# ...                                          ...       ...
# 991      54e52607e4b01191dc064966  736228.000000  3.000000
# 995      54e52607e4b01191dc064966  736337.666667  2.666667
# 996      54e52607e4b01191dc064966  736289.500000  2.450000
# 997      54e52607e4b01191dc064966  736282.000000  3.000000
# 999      54e52607e4b01191dc064966  736291.050000  2.850000
#
# [4377 rows x 2 columns]

# %%
votes_by_company = votes_grouped.groupby('companyAlias').mean().reset_index().sort_values(by='vote')

# %%
fig, ax = plt.subplots(figsize=(13,13))
ax = sns.barplot(data=votes_by_company, y='companyAlias', x='vote')

# %%
merged_company_data = votes_by_company.merge(sorted_commentInteractions)[['companyAlias','liked','vote']]

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 10))

fig.suptitle('votes and liked by company')

sns.barplot(ax=axes[0], data=merged_company_data, x='vote', y='companyAlias')
g2 = sns.barplot(ax=axes[1], data=merged_company_data, x='liked', y='companyAlias')
g2.set(ylabel=None)
g2.set(yticklabels=[])
plt.show()

# %% [markdown]
# # 1.4 Comments data
#
# ## It is possible to find data about the comments written in the app in the anon_comments.csv file, and it has the following structure:
#
#     employee: An integer id that identifies an amployee inside a company.
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#     commentDate: String representing the date a given comment was written.
#     commentId: A unique id for a given comment.
#     comment: Anonimized comment. It has the same length as the original comment.
#     likes: Number of likes that the comment received.
#     dislikes: Number of dislikes that the comment received.

# %%
comments_clean_anonimized
# Out:
#        employee              companyAlias                 commentId  \
# 0           307  56aec740f1ef260003e307d6  58d018d7e010990004e38070
# 1           382  56aec740f1ef260003e307d6  58d0179ae010990004e3806d
# 2           172  56aec740f1ef260003e307d6  58cff8cde010990004e37f6a
# 3           135  56aec740f1ef260003e307d6  58cfefeee010990004e37f60
# 4           225  56aec740f1ef260003e307d6  58cfd9b4e010990004e37f52
# ...         ...                       ...                       ...
# 82751       118  58a728a0e75bda00042a3468  58ae85a69fd38f00045eeee4
# 82752       -10  58a728a0e75bda00042a3468  58ae7fa19fd38f00045eeee2
# 82753        -8  58a728a0e75bda00042a3468  58adbfcbb8242400048bf8c1
# 82754        64  58a728a0e75bda00042a3468  58adba78b8242400048bf8b5
# 82755       361  58a728a0e75bda00042a3468  58adb214b8242400048bf8a6
#
#                                                      txt  likes  dislikes  \
# 0      **********************************************...    4.0       0.0
# 1                          *****************************    1.0       2.0
# 2                            ***************************    3.0       0.0
# 3                            ***************************    1.0       1.0
# 4                      *********************************    3.0       2.0
# ...                                                  ...    ...       ...
# 82751  **********************************************...    1.0       0.0
# 82752                                  *****************    2.0       0.0
# 82753                             **********************    5.0       0.0
# 82754                 **********************************    3.0       0.0
# 82755                                                NaN    NaN       NaN
#
#                         commentDate
# 0      Mon Mar 20 19:00:17 CET 2017
# 1      Mon Mar 20 18:55:16 CET 2017
# 2      Mon Mar 20 16:44:02 CET 2017
# 3      Mon Mar 20 16:06:08 CET 2017
# 4      Mon Mar 20 14:30:50 CET 2017
# ...                             ...
# 82751  Thu Feb 23 07:44:48 CET 2017
# 82752  Thu Feb 23 07:22:12 CET 2017
# 82753  Wed Feb 22 17:43:39 CET 2017
# 82754  Wed Feb 22 17:20:07 CET 2017
# 82755                           NaN
#
# [82756 rows x 7 columns]

# %%
dates = pd.to_datetime(comments_clean_anonimized.commentDate)

# %%
dates.hist()
# Out:
# <AxesSubplot:>

# %%
# comments_clean_anonimized = comments_clean_anonimized[comments_clean_anonimized.employee > 0]
comments_clean_anonimized['uid'] = comments_clean_anonimized.employee.apply(str) + comments_clean_anonimized.companyAlias
comments_clean_anonimized = comments_clean_anonimized.drop_duplicates()
# Out:
# <ipython-input-71-9a8c4f3f44b9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_clean_anonimized['uid'] = comments_clean_anonimized.employee.apply(str) + comments_clean_anonimized.companyAlias

# %%
comments_clean_anonimized['txt_len'] = comments_clean_anonimized.txt.str.len()
comments_clean_anonimized.txt_len = comments_clean_anonimized.txt_len.fillna(0)

# %%
comments_clean_anonimized.commentDate = dates
comments_clean_anonimized.commentDate = comments_clean_anonimized.commentDate.map(dt.datetime.toordinal)

# %%
comments_clean_anonimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38994 entries, 0 to 82755
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   employee      38994 non-null  int64
#  1   companyAlias  38994 non-null  object
#  2   commentId     38994 non-null  object
#  3   txt           38892 non-null  object
#  4   likes         38993 non-null  float64
#  5   dislikes      38993 non-null  float64
#  6   commentDate   38994 non-null  int64
#  7   uid           38994 non-null  object
#  8   txt_len       38994 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.0+ MB

# %%
def calculate_activity_over_time(df):
    slopes = []
    users = df.uid.unique()
    for user in users:
        y = df[df.uid == user].commentDate.values
        len_y = len(y)
        x = list(range(0,len_y))
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        slopes.append(slope)
    return slopes

# %%
def calculate_activity_over_time2(df):
    activities = []
    users = df.uid.unique()
    for user in users:
        activity = df[df.uid == user].commentDate.max() - df[df.uid == user].commentDate.min()
        activities.append(activity)
    return activities

# %%
activity = calculate_activity_over_time2(comments_clean_anonimized)

# %%
# we negate the slopes because the data is from the latest to the oldest
mynegslopes = [ -x for x in activity]

# %%
df_activity = pd.DataFrame(list(zip(activity, comments_clean_anonimized.uid.unique())),
               columns =['activity', 'uid'])
#df_activity = df_activity.fillna(0)

# %%
df_activity.activity.isna().sum()
# Out:
# 0

# %%
comments_clean_anonimized[comments_clean_anonimized.uid == '17256aec740f1ef260003e307d6'].commentDate.max()
# Out:
# 736408

# %%
df_activity[df_activity.uid == '17256aec740f1ef260003e307d6']
# Out:
#    activity                          uid
# 2       367  17256aec740f1ef260003e307d6

# %%
comments_clean_anonimized[comments_clean_anonimized.uid == '36158a728a0e75bda00042a3468']
# Out:
#        employee              companyAlias                 commentId  \
# 80571       361  58a728a0e75bda00042a3468  58cbf6321da6390004e09a0d
# 80573       361  58a728a0e75bda00042a3468  58cbf6321da6390004e09a0c
# 80676       361  58a728a0e75bda00042a3468  58ca4419bd760e00043f198a
# 80812       361  58a728a0e75bda00042a3468  58c69f4bdc635b0004321d93
# 80866       361  58a728a0e75bda00042a3468  58c2b19d2472460004036c7c
# 80912       361  58a728a0e75bda00042a3468  58c17a119653a3000411721f
# 81058       361  58a728a0e75bda00042a3468  58be6eb70d9dcc0004d8538d
# 81463       361  58a728a0e75bda00042a3468  58b03b20e5efa8000476762a
# 81539       361  58a728a0e75bda00042a3468  58aee1059fd38f00045eef58
# 81594       361  58a728a0e75bda00042a3468  58adb214b8242400048bf8a6
# 82755       361  58a728a0e75bda00042a3468  58adb214b8242400048bf8a6
#
#                                                      txt  likes  dislikes  \
# 80571            ***************************************   18.0       9.0
# 80573  **********************************************...   15.0       0.0
# 80676  **********************************************...   18.0       1.0
# 80812  **********************************************...   50.0       0.0
# 80866                                            *******    1.0       2.0
# 80912  **********************************************...   24.0       0.0
# 81058  **********************************************...    5.0       3.0
# 81463  **********************************************...   14.0       7.0
# 81539  **********************************************...    6.0       2.0
# 81594  **********************************************...   10.0       0.0
# 82755                                                NaN    NaN       NaN
#
#        commentDate                          uid  txt_len
# 80571       736405  36158a728a0e75bda00042a3468     39.0
# 80573       736405  36158a728a0e75bda00042a3468    115.0
# 80676       736404  36158a728a0e75bda00042a3468    189.0
# 80812       736401  36158a728a0e75bda00042a3468    329.0
# 80866       736398  36158a728a0e75bda00042a3468      7.0
# 80912       736397  36158a728a0e75bda00042a3468    138.0
# 81058       736395  36158a728a0e75bda00042a3468     90.0
# 81463       736384  36158a728a0e75bda00042a3468    147.0
# 81539       736383  36158a728a0e75bda00042a3468     85.0
# 81594       736382  36158a728a0e75bda00042a3468     77.0
# 82755            1  36158a728a0e75bda00042a3468      0.0

# %%
comments_clean_anonimized.isna().sum()
# txt with NaN = 0 to len.
# Out:
# employee          0
# companyAlias      0
# commentId         0
# txt             102
# likes             1
# dislikes          1
# commentDate       0
# uid               0
# txt_len           0
# dtype: int64

# %%
df_activity[df_activity.activity > 30474]
# Out:
#       activity                          uid
# 2726    736404  36158a728a0e75bda00042a3468

# %%
df_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2881 entries, 0 to 2880
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   activity  2881 non-null   int64
#  1   uid       2881 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 45.1+ KB

# %%
comments_clean_anonimized.describe()
# Out:
#            employee         likes      dislikes    commentDate       txt_len
# count  38994.000000  38993.000000  38993.000000   38994.000000  38994.000000
# mean     150.956634      7.002488      1.297977  736186.873801    102.137508
# std      157.279482      7.773628      2.748012    3731.725183    202.660076
# min        1.000000      0.000000      0.000000       1.000000      0.000000
# 25%       38.000000      2.000000      0.000000  736130.000000     27.000000
# 50%      112.000000      4.000000      0.000000  736246.000000     57.000000
# 75%      207.000000     10.000000      1.000000  736320.000000    118.000000
# max      999.000000     86.000000     53.000000  736408.000000  29057.000000

# %%
comments_clean_anonimized[['commentId','uid']]
# Out:
#                       commentId                          uid
# 0      58d018d7e010990004e38070  30756aec740f1ef260003e307d6
# 1      58d0179ae010990004e3806d  38256aec740f1ef260003e307d6
# 2      58cff8cde010990004e37f6a  17256aec740f1ef260003e307d6
# 3      58cfefeee010990004e37f60  13556aec740f1ef260003e307d6
# 4      58cfd9b4e010990004e37f52  22556aec740f1ef260003e307d6
# ...                         ...                          ...
# 81633  58a7bafb58bf270004ed12fb    558a728a0e75bda00042a3468
# 81634  58a73c93e75bda00042a3491   1058a728a0e75bda00042a3468
# 81635  58a7306fe75bda00042a3474    258a728a0e75bda00042a3468
# 81636  58a73005e75bda00042a3472    158a728a0e75bda00042a3468
# 82755  58adb214b8242400048bf8a6  36158a728a0e75bda00042a3468
#
# [38994 rows x 2 columns]

# %%
comments_of_churned_people = comments_clean_anonimized[['commentId','uid']][comments_clean_anonimized['uid'].isin(personnes_absentes)]
comments_of_churned_people
# Out:
#                       commentId                          uid
# 936    5873418574f9080004b44f2a  23256aec740f1ef260003e307d6
# 1160   585a4026da8c4a000470c4f4  23256aec740f1ef260003e307d6
# 1176   5858f02ef830b00004e7a03e  23256aec740f1ef260003e307d6
# 1370   5847ec0ff77d9e00047003b0  15556aec740f1ef260003e307d6
# 1371   5847eb09f77d9e00047003af  23256aec740f1ef260003e307d6
# ...                         ...                          ...
# 75797  577e204470596c0003e535f3  1615742d699f839a10003a407d2
# 75819  577cd18d5235410003d2ea41  1615742d699f839a10003a407d2
# 75884  577a10112736100003a49d6a  1615742d699f839a10003a407d2
# 75888  5778fa9003dac900038c8c6c  1615742d699f839a10003a407d2
# 75907  57779dbaa0e76d0003c90ec7  1615742d699f839a10003a407d2
#
# [3852 rows x 2 columns]

# %%
commentInteractions[commentInteractions.commentId.isin(comments_of_churned_people)]
# Out:
# Empty DataFrame
# Columns: [employee, companyAlias, liked, disliked, commentId, uid]
# Index: []

# %%
people_which_liked_churned_people = commentInteractions[(commentInteractions.commentId.isin(comments_of_churned_people.commentId)) & (commentInteractions.liked == 1)]
people_which_liked_churned_people
# Out:
#         employee              companyAlias  liked  disliked  \
# 9084          24  56aec740f1ef260003e307d6      1         0
# 9085         491  56aec740f1ef260003e307d6      1         0
# 10591        139  56aec740f1ef260003e307d6      1         0
# 10592        136  56aec740f1ef260003e307d6      1         0
# 10593        108  56aec740f1ef260003e307d6      1         0
# ...          ...                       ...    ...       ...
# 304260         6  5742d699f839a10003a407d2      1         0
# 308061        68  5742d699f839a10003a407d2      1         0
# 308062        11  5742d699f839a10003a407d2      1         0
# 308063        33  5742d699f839a10003a407d2      1         0
# 308064         1  5742d699f839a10003a407d2      1         0
#
#                        commentId                          uid
# 9084    5873418574f9080004b44f2a   2456aec740f1ef260003e307d6
# 9085    5873418574f9080004b44f2a  49156aec740f1ef260003e307d6
# 10591   5858f02ef830b00004e7a03e  13956aec740f1ef260003e307d6
# 10592   5858f02ef830b00004e7a03e  13656aec740f1ef260003e307d6
# 10593   5858f02ef830b00004e7a03e  10856aec740f1ef260003e307d6
# ...                          ...                          ...
# 304260  576ba6ef60bb1c0003016fbc    65742d699f839a10003a407d2
# 308061  5742f6d3f839a10003a40815   685742d699f839a10003a407d2
# 308062  5742f6d3f839a10003a40815   115742d699f839a10003a407d2
# 308063  5742f6d3f839a10003a40815   335742d699f839a10003a407d2
# 308064  5742f6d3f839a10003a40815    15742d699f839a10003a407d2
#
# [27049 rows x 6 columns]

# %%
commentInteractions['liked_churned_people'] = np.where(commentInteractions.uid.isin(people_which_liked_churned_people.uid), 1, 0)

# %%
commentInteractions
# Out:
#         employee              companyAlias liked disliked  \
# 0            307  56aec740f1ef260003e307d6  True    False
# 1             36  56aec740f1ef260003e307d6  True    False
# 2            276  56aec740f1ef260003e307d6  True    False
# 3             24  56aec740f1ef260003e307d6  True    False
# 4            382  56aec740f1ef260003e307d6  True    False
# ...          ...                       ...   ...      ...
# 336955       -49  58a728a0e75bda00042a3468  True    False
# 336956       232  58a728a0e75bda00042a3468  True    False
# 336957       -25  58a728a0e75bda00042a3468  True    False
# 336958        36  58a728a0e75bda00042a3468  True    False
# 336959       -47                   58a728a   NaN      NaN
#
#                        commentId
# 0       58d018d7e010990004e38070
# 1       58d018d7e010990004e38070
# 2       58d018d7e010990004e38070
# 3       58d018d7e010990004e38070
# 4       58d0179ae010990004e3806d
# ...                          ...
# 336955  58ad8adeb8242400048bf834
# 336956  58ad8adeb8242400048bf834
# 336957  58ad8adeb8242400048bf834
# 336958  58ad8adeb8242400048bf834
# 336959                       NaN
#
# [336960 rows x 5 columns]

# %%
commentInteractions[commentInteractions.uid == '1005641f96713664c000332c8cd']
# Out:
#         employee              companyAlias  liked  disliked  \
# 186908       100  5641f96713664c000332c8cd      1         0
# 186919       100  5641f96713664c000332c8cd      1         0
# 186991       100  5641f96713664c000332c8cd      1         0
# 187011       100  5641f96713664c000332c8cd      0         1
# 187030       100  5641f96713664c000332c8cd      1         0
# ...          ...                       ...    ...       ...
# 204742       100  5641f96713664c000332c8cd      1         0
# 204793       100  5641f96713664c000332c8cd      0         1
# 204869       100  5641f96713664c000332c8cd      1         0
# 206315       100  5641f96713664c000332c8cd      1         0
# 206362       100  5641f96713664c000332c8cd      1         0
#
#                        commentId                          uid  \
# 186908  57f6c357e308980003c285c0  1005641f96713664c000332c8cd
# 186919  57f6be1044892f00033aa1ad  1005641f96713664c000332c8cd
# 186991  57f673cd44892f00033aa176  1005641f96713664c000332c8cd
# 187011  57f6669944892f00033aa16d  1005641f96713664c000332c8cd
# 187030  57f61ac944892f00033aa12e  1005641f96713664c000332c8cd
# ...                          ...                          ...
# 204742  57541d0b01dbb2000395d2d8  1005641f96713664c000332c8cd
# 204793  5753fade01dbb2000395d2d1  1005641f96713664c000332c8cd
# 204869  5752da225cdb520003700bd4  1005641f96713664c000332c8cd
# 206315  573f6e723517490003ef772d  1005641f96713664c000332c8cd
# 206362  573ed9ff3517490003ef76ed  1005641f96713664c000332c8cd
#
#         liked_churned_people
# 186908                     1
# 186919                     1
# 186991                     1
# 187011                     1
# 187030                     1
# ...                      ...
# 204742                     1
# 204793                     1
# 204869                     1
# 206315                     1
# 206362                     1
#
# [281 rows x 7 columns]

# %%
commentInteractions.groupby('uid').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-5296421902a0> in <module>
# ----> 1 commentInteractions.groupby('uid').sum()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'uid'

# %%
total_interaction_by_user = commentInteractions.groupby('uid').sum().drop('employee', axis = 1)
total_interaction_by_user.liked_churned_people = np.where(total_interaction_by_user.liked_churned_people == 0, 0, 1)
total_interaction_by_user
# Out:
#                              liked  disliked  liked_churned_people
# uid
# 10053a2dd43e4b01cc02f1e9011     60        55                     0
# 1005641f96713664c000332c8cd    191        90                     1
# 10056aec740f1ef260003e307d6    288         2                     1
# 10056e2a905e3b6fe0003e32855     11         0                     0
# 10056fd2b64f41c670003f643c8      5         0                     1
# ...                            ...       ...                   ...
# 9957bb2f0b3bae540003a8d453      33        20                     0
# 9957dd2d6a4018d9000339ca43       1         0                     0
# 99581b08041a0ef8000308aef6      31        33                     0
# 99654e52607e4b01191dc064966     20         2                     1
# 99954e52607e4b01191dc064966      1         1                     1
#
# [3147 rows x 3 columns]

# %%
total_interaction_by_user.liked_churned_people.hist()
# Out:
# <AxesSubplot:>

# %%
comments_clean_anonimized.likes.sum()
# Out:
# 273048.0

# %%
comments_clean_anonimized.dislikes.sum()
# Out:
# 50612.0

# %%
comments_grouped = comments_clean_anonimized.groupby('companyAlias').mean().drop('employee', axis = 1).sort_values(by=['likes'], ascending = False)
comments_grouped.head()
# Out:
#                               likes  dislikes    commentDate     txt_len
# companyAlias
# 5742d699f839a10003a407d2  14.238628  1.112975  736238.606264  198.459732
# 5641f96713664c000332c8cd  12.640990  2.844197  736231.145347  140.407808
# 574c5ade56b6300003009965  10.133936  1.902629  736221.328677  126.624486
# 58a728a0e75bda00042a3468  10.071766  2.841360  735700.469811   98.829245
# 57d956302a040a00036a8905   9.160800  0.902400  736277.447200  105.902400

# %%
sns.regplot(data=comments_grouped, x="txt_len", y="likes",  scatter_kws={"s": 80}, ci=None, robust=True)
# Out:
# <AxesSubplot:xlabel='txt_len', ylabel='likes'>

# %%
sns.regplot(data=comments_grouped, x="txt_len", y="dislikes", robust= True, ci=None)
# Out:
# <AxesSubplot:xlabel='txt_len', ylabel='dislikes'>

# %% [markdown]
# #  Datasets merger

# %%
churn.sample(2) 
# numVotes is not up to date !!!
# Out:
#       employee              companyAlias  numVotes     lastParticipationDate  \
# 90          94  56aec740f1ef260003e307d6       100 2017-03-10 01:00:00+01:00
# 3146        90  574c5ade56b6300003009965        28 2017-03-14 10:23:04+01:00
#
#       stillExists                         uid
# 90           True  9456aec740f1ef260003e307d6
# 3146         True  90574c5ade56b6300003009965

# %%
churn.numVotes.sum()
# Out:
# 222002

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3944 entries, 0 to 4845
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3944 non-null   int64
#  1   companyAlias           3944 non-null   object
#  2   numVotes               3944 non-null   int64
#  3   lastParticipationDate  3944 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            3944 non-null   bool
#  5   uid                    3944 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 348.7+ KB

# %%
total_interaction_by_user.sample(2)
# Out:
#                             liked  disliked  liked_churned_people
# uid
# 15809cc9eff2ea40003fda44d      12         1                     0
# 20573f2c4a3517490003ef7710      7         2                     0

# %%
total_interaction_by_user.head()
# Out:
#                              liked  disliked  liked_churned_people
# uid
# 10053a2dd43e4b01cc02f1e9011     60        55                     0
# 1005641f96713664c000332c8cd    191        90                     1
# 10056aec740f1ef260003e307d6    288         2                     1
# 10056e2a905e3b6fe0003e32855     11         0                     0
# 10056fd2b64f41c670003f643c8      5         0                     1

# %%
total_interaction_by_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3147 entries, 10053a2dd43e4b01cc02f1e9011 to 99954e52607e4b01191dc064966
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   liked                 3147 non-null   int64
#  1   disliked              3147 non-null   int64
#  2   liked_churned_people  3147 non-null   int64
# dtypes: int64(3)
# memory usage: 98.3+ KB

# %%
votes.sample(2)
# Out:
#         employee              companyAlias  voteDate  vote  \
# 197691       107  5742d699f839a10003a407d2    736249     4
# 86361        114  54e52607e4b01191dc064966    736156     3
#
#                                 uid
# 197691  1075742d699f839a10003a407d2
# 86361   11454e52607e4b01191dc064966

# %%
votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221145 entries, 0 to 221231
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   employee      221145 non-null  int64
#  1   companyAlias  221145 non-null  object
#  2   voteDate      221145 non-null  int64
#  3   vote          221145 non-null  int64
#  4   uid           221145 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 10.1+ MB

# %%
comments_clean_anonimized.sample(2)
# Out:
#        employee              companyAlias                 commentId  \
# 20967        92  581b08041a0ef8000308aef6  583f74be79244000040dd4b8
# 59238       201  574c5ade56b6300003009965  57e7b3026a5b18000363291c
#
#                                                      txt  likes  dislikes  \
# 20967                      *****************************    4.0       0.0
# 59238  **********************************************...    5.0       2.0
#
#        commentDate                          uid  txt_len
# 20967       736299   92581b08041a0ef8000308aef6     29.0
# 59238       736232  201574c5ade56b6300003009965    103.0

# %%
comments_clean_anonimized[comments_clean_anonimized.uid == '10053a2dd43e4b01cc02f1e9011']
# Out:
#        employee              companyAlias                 commentId  \
# 63457       100  53a2dd43e4b01cc02f1e9011  57e97335bad95d00030858c3
# 63527       100  53a2dd43e4b01cc02f1e9011  57c97219a550ce0003eb5e89
# 63803       100  53a2dd43e4b01cc02f1e9011  57759786f907d700031600c3
# 63848       100  53a2dd43e4b01cc02f1e9011  576c27f6c7cda30003363ce5
# 63884       100  53a2dd43e4b01cc02f1e9011  5765783a44bef90003294c13
# 63924       100  53a2dd43e4b01cc02f1e9011  57603c51fdfb340003a74c4b
# 64059       100  53a2dd43e4b01cc02f1e9011  574b5a16b62d4600039c9148
# 64087       100  53a2dd43e4b01cc02f1e9011  5746e87755015a00032e11fa
# 64162       100  53a2dd43e4b01cc02f1e9011  573ce28a44d85900031c3b7d
# 64175       100  53a2dd43e4b01cc02f1e9011  573b8b0a8a14ae0003ac74c0
# 64474       100  53a2dd43e4b01cc02f1e9011  571d344462947b00037635b0
# 64490       100  53a2dd43e4b01cc02f1e9011  571b846deaac4e00034511fd
# 64581       100  53a2dd43e4b01cc02f1e9011  5716976a429f530003ee60b2
# 64746       100  53a2dd43e4b01cc02f1e9011  570c1d7a78d7b0000320afdb
# 64831       100  53a2dd43e4b01cc02f1e9011  57067af7e0039c00038681a9
# 64846       100  53a2dd43e4b01cc02f1e9011  5705965403498b0003e65553
# 65079       100  53a2dd43e4b01cc02f1e9011  56f9674427be6b0003bedb19
# 65252       100  53a2dd43e4b01cc02f1e9011  56f05d08b2961a0003c73b41
#
#                                                      txt  likes  dislikes  \
# 63457  **********************************************...    1.0       2.0
# 63527  **********************************************...    2.0       2.0
# 63803  **********************************************...    2.0       4.0
# 63848                 **********************************    1.0       2.0
# 63884  **********************************************...    1.0       3.0
# 63924  **********************************************...    1.0       1.0
# 64059  **********************************************...    1.0       3.0
# 64087  **********************************************...    3.0       5.0
# 64162  **********************************************...    2.0       5.0
# 64175       ********************************************    1.0       2.0
# 64474                           ************************    0.0       0.0
# 64490  **********************************************...    1.0       2.0
# 64581  **********************************************...    8.0       0.0
# 64746  **********************************************...    6.0       1.0
# 64831  **********************************************...    1.0       4.0
# 64846  **********************************************...    4.0       1.0
# 65079  **********************************************...   12.0       3.0
# 65252  **********************************************...    5.0       2.0
#
#        commentDate                          uid  txt_len
# 63457       736233  10053a2dd43e4b01cc02f1e9011    522.0
# 63527       736209  10053a2dd43e4b01cc02f1e9011     81.0
# 63803       736146  10053a2dd43e4b01cc02f1e9011    201.0
# 63848       736138  10053a2dd43e4b01cc02f1e9011     34.0
# 63884       736133  10053a2dd43e4b01cc02f1e9011    252.0
# 63924       736129  10053a2dd43e4b01cc02f1e9011    239.0
# 64059       736113  10053a2dd43e4b01cc02f1e9011    157.0
# 64087       736110  10053a2dd43e4b01cc02f1e9011    217.0
# 64162       736102  10053a2dd43e4b01cc02f1e9011    142.0
# 64175       736101  10053a2dd43e4b01cc02f1e9011     44.0
# 64474       736078  10053a2dd43e4b01cc02f1e9011     24.0
# 64490       736077  10053a2dd43e4b01cc02f1e9011    114.0
# 64581       736073  10053a2dd43e4b01cc02f1e9011    272.0
# 64746       736065  10053a2dd43e4b01cc02f1e9011    169.0
# 64831       736061  10053a2dd43e4b01cc02f1e9011     89.0
# 64846       736061  10053a2dd43e4b01cc02f1e9011    191.0
# 65079       736051  10053a2dd43e4b01cc02f1e9011    410.0
# 65252       736044  10053a2dd43e4b01cc02f1e9011    203.0

# %%
comments_clean_anonimized[comments_clean_anonimized.uid == '10053a2dd43e4b01cc02f1e9011']
# Out:
#        employee              companyAlias                 commentId  \
# 63457       100  53a2dd43e4b01cc02f1e9011  57e97335bad95d00030858c3
# 63527       100  53a2dd43e4b01cc02f1e9011  57c97219a550ce0003eb5e89
# 63803       100  53a2dd43e4b01cc02f1e9011  57759786f907d700031600c3
# 63848       100  53a2dd43e4b01cc02f1e9011  576c27f6c7cda30003363ce5
# 63884       100  53a2dd43e4b01cc02f1e9011  5765783a44bef90003294c13
# 63924       100  53a2dd43e4b01cc02f1e9011  57603c51fdfb340003a74c4b
# 64059       100  53a2dd43e4b01cc02f1e9011  574b5a16b62d4600039c9148
# 64087       100  53a2dd43e4b01cc02f1e9011  5746e87755015a00032e11fa
# 64162       100  53a2dd43e4b01cc02f1e9011  573ce28a44d85900031c3b7d
# 64175       100  53a2dd43e4b01cc02f1e9011  573b8b0a8a14ae0003ac74c0
# 64474       100  53a2dd43e4b01cc02f1e9011  571d344462947b00037635b0
# 64490       100  53a2dd43e4b01cc02f1e9011  571b846deaac4e00034511fd
# 64581       100  53a2dd43e4b01cc02f1e9011  5716976a429f530003ee60b2
# 64746       100  53a2dd43e4b01cc02f1e9011  570c1d7a78d7b0000320afdb
# 64831       100  53a2dd43e4b01cc02f1e9011  57067af7e0039c00038681a9
# 64846       100  53a2dd43e4b01cc02f1e9011  5705965403498b0003e65553
# 65079       100  53a2dd43e4b01cc02f1e9011  56f9674427be6b0003bedb19
# 65252       100  53a2dd43e4b01cc02f1e9011  56f05d08b2961a0003c73b41
#
#                                                      txt  likes  dislikes  \
# 63457  **********************************************...    1.0       2.0
# 63527  **********************************************...    2.0       2.0
# 63803  **********************************************...    2.0       4.0
# 63848                 **********************************    1.0       2.0
# 63884  **********************************************...    1.0       3.0
# 63924  **********************************************...    1.0       1.0
# 64059  **********************************************...    1.0       3.0
# 64087  **********************************************...    3.0       5.0
# 64162  **********************************************...    2.0       5.0
# 64175       ********************************************    1.0       2.0
# 64474                           ************************    0.0       0.0
# 64490  **********************************************...    1.0       2.0
# 64581  **********************************************...    8.0       0.0
# 64746  **********************************************...    6.0       1.0
# 64831  **********************************************...    1.0       4.0
# 64846  **********************************************...    4.0       1.0
# 65079  **********************************************...   12.0       3.0
# 65252  **********************************************...    5.0       2.0
#
#        commentDate                          uid  txt_len
# 63457       736233  10053a2dd43e4b01cc02f1e9011    522.0
# 63527       736209  10053a2dd43e4b01cc02f1e9011     81.0
# 63803       736146  10053a2dd43e4b01cc02f1e9011    201.0
# 63848       736138  10053a2dd43e4b01cc02f1e9011     34.0
# 63884       736133  10053a2dd43e4b01cc02f1e9011    252.0
# 63924       736129  10053a2dd43e4b01cc02f1e9011    239.0
# 64059       736113  10053a2dd43e4b01cc02f1e9011    157.0
# 64087       736110  10053a2dd43e4b01cc02f1e9011    217.0
# 64162       736102  10053a2dd43e4b01cc02f1e9011    142.0
# 64175       736101  10053a2dd43e4b01cc02f1e9011     44.0
# 64474       736078  10053a2dd43e4b01cc02f1e9011     24.0
# 64490       736077  10053a2dd43e4b01cc02f1e9011    114.0
# 64581       736073  10053a2dd43e4b01cc02f1e9011    272.0
# 64746       736065  10053a2dd43e4b01cc02f1e9011    169.0
# 64831       736061  10053a2dd43e4b01cc02f1e9011     89.0
# 64846       736061  10053a2dd43e4b01cc02f1e9011    191.0
# 65079       736051  10053a2dd43e4b01cc02f1e9011    410.0
# 65252       736044  10053a2dd43e4b01cc02f1e9011    203.0

# %%
comments_clean_anonimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38994 entries, 0 to 82755
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   employee      38994 non-null  int64
#  1   companyAlias  38994 non-null  object
#  2   commentId     38994 non-null  object
#  3   txt           38892 non-null  object
#  4   likes         38993 non-null  float64
#  5   dislikes      38993 non-null  float64
#  6   commentDate   38994 non-null  int64
#  7   uid           38994 non-null  object
#  8   txt_len       38994 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.0+ MB

# %%
comments_light = comments_clean_anonimized.drop(['employee','companyAlias','txt', 'commentDate'], axis=1).dropna()
comments_light
# Out:
#                       commentId  likes  dislikes                          uid  \
# 0      58d018d7e010990004e38070    4.0       0.0  30756aec740f1ef260003e307d6
# 1      58d0179ae010990004e3806d    1.0       2.0  38256aec740f1ef260003e307d6
# 2      58cff8cde010990004e37f6a    3.0       0.0  17256aec740f1ef260003e307d6
# 3      58cfefeee010990004e37f60    1.0       1.0  13556aec740f1ef260003e307d6
# 4      58cfd9b4e010990004e37f52    3.0       2.0  22556aec740f1ef260003e307d6
# ...                         ...    ...       ...                          ...
# 81632  58a8a81158bf270004ed1326    7.0       5.0    658a728a0e75bda00042a3468
# 81633  58a7bafb58bf270004ed12fb    0.0       0.0    558a728a0e75bda00042a3468
# 81634  58a73c93e75bda00042a3491    4.0       0.0   1058a728a0e75bda00042a3468
# 81635  58a7306fe75bda00042a3474    1.0       0.0    258a728a0e75bda00042a3468
# 81636  58a73005e75bda00042a3472   12.0       0.0    158a728a0e75bda00042a3468
#
#        txt_len
# 0         62.0
# 1         29.0
# 2         27.0
# 3         27.0
# 4         33.0
# ...        ...
# 81632     81.0
# 81633    111.0
# 81634    126.0
# 81635     53.0
# 81636     52.0
#
# [38993 rows x 5 columns]

# %%
comments_light[comments_light.uid == '158a728a0e75bda00042a3468']
# Out:
#                       commentId  likes  dislikes                        uid  \
# 80488  58cff0c9e010990004e37f62    5.0       0.0  158a728a0e75bda00042a3468
# 80588  58cbe1851da6390004e099c6    2.0       1.0  158a728a0e75bda00042a3468
# 80593  58cbe1851da6390004e099c5    1.0       0.0  158a728a0e75bda00042a3468
# 80659  58ca639c92db640004f9548a    3.0       1.0  158a728a0e75bda00042a3468
# 80820  58c68714dc635b0004321c7d    2.0       0.0  158a728a0e75bda00042a3468
# 81095  58bd66cb31608400049b312f    3.0       0.0  158a728a0e75bda00042a3468
# 81142  58b97c63e75bf80004df634c   12.0       1.0  158a728a0e75bda00042a3468
# 81260  58b70c61917c350004dc0ba7   12.0       0.0  158a728a0e75bda00042a3468
# 81480  58b01027e5efa800047675fa    1.0       2.0  158a728a0e75bda00042a3468
# 81549  58aec97f9fd38f00045eef47    6.0       1.0  158a728a0e75bda00042a3468
# 81618  58ad693c0a0c980004071d74    3.0       0.0  158a728a0e75bda00042a3468
# 81624  58ac79fe5a227800040ff29c   21.0       0.0  158a728a0e75bda00042a3468
# 81631  58aab62159d9210004a4728c    0.0       0.0  158a728a0e75bda00042a3468
# 81636  58a73005e75bda00042a3472   12.0       0.0  158a728a0e75bda00042a3468
#
#        txt_len
# 80488    173.0
# 80588     47.0
# 80593     82.0
# 80659     59.0
# 80820     21.0
# 81095     78.0
# 81142    173.0
# 81260     76.0
# 81480    109.0
# 81549     45.0
# 81618     93.0
# 81624    114.0
# 81631     21.0
# 81636     52.0

# %%
total_interaction_by_user
# Out:
#                              liked  disliked  liked_churned_people
# uid
# 10053a2dd43e4b01cc02f1e9011     60        55                     0
# 1005641f96713664c000332c8cd    191        90                     1
# 10056aec740f1ef260003e307d6    288         2                     1
# 10056e2a905e3b6fe0003e32855     11         0                     0
# 10056fd2b64f41c670003f643c8      5         0                     1
# ...                            ...       ...                   ...
# 9957bb2f0b3bae540003a8d453      33        20                     0
# 9957dd2d6a4018d9000339ca43       1         0                     0
# 99581b08041a0ef8000308aef6      31        33                     0
# 99654e52607e4b01191dc064966     20         2                     1
# 99954e52607e4b01191dc064966      1         1                     1
#
# [3147 rows x 3 columns]

# %%
churn.drop(['employee','companyAlias','lastParticipationDate'], axis=1).merge(total_interaction_by_user, left_on='uid', right_on='uid')
# Out:
#       numVotes  stillExists                          uid  liked  disliked  \
# 0            4         True  51256aec740f1ef260003e307d6      6         0
# 1           72         True    256aec740f1ef260003e307d6     60        12
# 2           14        False  48756aec740f1ef260003e307d6      1         0
# 3           14        False  48756aec740f1ef260003e307d6      1         0
# 4           22         True    356aec740f1ef260003e307d6      6         5
# ...        ...          ...                          ...    ...       ...
# 3062         4         True  84958a728a0e75bda00042a3468     11         0
# 3063         3         True  85058a728a0e75bda00042a3468      8         4
# 3064         3         True  85158a728a0e75bda00042a3468     10         4
# 3065         5         True  85258a728a0e75bda00042a3468     28         8
# 3066         3         True  85458a728a0e75bda00042a3468     15        11
#
#       liked_churned_people
# 0                        0
# 1                        1
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 3062                     0
# 3063                     0
# 3064                     0
# 3065                     0
# 3066                     0
#
# [3067 rows x 6 columns]

# %%
df = (churn.drop(['employee','companyAlias','lastParticipationDate'], axis=1).merge(total_interaction_by_user, left_on='uid', right_on='uid').
        merge(votes_grouped_by_user_with_happy, left_on='uid', right_on='uid').merge(comments_light.groupby('uid').mean(), left_on='uid', right_on='uid'))

# %%
df
# Out:
#       numVotes  stillExists                          uid  liked  disliked  \
# 0            4         True  51256aec740f1ef260003e307d6      6         0
# 1           72         True    256aec740f1ef260003e307d6     60        12
# 2           14        False  48756aec740f1ef260003e307d6      1         0
# 3           14        False  48756aec740f1ef260003e307d6      1         0
# 4           22         True    356aec740f1ef260003e307d6      6         5
# ...        ...          ...                          ...    ...       ...
# 2515         4         True  84658a728a0e75bda00042a3468      2         0
# 2516         5         True  84758a728a0e75bda00042a3468     35         5
# 2517         4         True  84958a728a0e75bda00042a3468     11         0
# 2518         3         True  85058a728a0e75bda00042a3468      8         4
# 2519         5         True  85258a728a0e75bda00042a3468     28         8
#
#       liked_churned_people       voteDate      vote  Happiness  Activity  \
# 0                        0  736365.500000  2.500000  -0.000000        37
# 1                        1  736168.361111  2.250000  -0.000805       406
# 2                        0  736276.785714  3.142857   0.006202        66
# 3                        0  736276.785714  3.142857   0.006202        66
# 4                        0  736120.318182  3.454545  -0.001876       378
# ...                    ...            ...       ...        ...       ...
# 2515                     0  736403.250000  3.250000   0.004926        10
# 2516                     0  736403.600000  3.200000   0.075163         9
# 2517                     0  736403.250000  2.750000  -0.257143         4
# 2518                     0  736403.666667  3.666667   0.285714         3
# 2519                     0  736405.000000  2.600000  -0.600000         4
#
#           likes  dislikes     txt_len
# 0      7.500000  1.000000  114.500000
# 1      5.428571  4.785714   59.571429
# 2      6.000000  0.000000   92.000000
# 3      6.000000  0.000000   92.000000
# 4      3.333333  0.888889   85.555556
# ...         ...       ...         ...
# 2515   0.000000  0.000000   15.000000
# 2516   1.000000  4.000000   17.000000
# 2517   1.000000  0.500000   56.500000
# 2518  10.333333  0.000000  115.333333
# 2519  10.666667  5.666667   87.000000
#
# [2520 rows x 13 columns]

# %%
df.describe()
# Out:
#           numVotes        liked     disliked  liked_churned_people  \
# count  2520.000000  2520.000000  2520.000000           2520.000000
# mean     72.100397   104.128968    19.315873              0.381746
# std      83.125215   205.021349    53.663481              0.485911
# min       2.000000     0.000000     0.000000              0.000000
# 25%      16.000000     9.000000     1.000000              0.000000
# 50%      41.000000    35.000000     4.000000              0.000000
# 75%      99.000000   107.250000    16.000000              1.000000
# max     740.000000  3151.000000   891.000000              1.000000
#
#             voteDate         vote    Happiness     Activity        likes  \
# count    2520.000000  2520.000000  2520.000000  2520.000000  2520.000000
# mean   736246.048374     2.916091     0.003069   187.576190     7.044922
# std       122.044765     0.650866     0.076144   154.328459     5.695156
# min    735656.111111     1.000000    -1.000000     1.000000     0.000000
# 25%    736193.045101     2.559535    -0.001646    70.000000     2.750000
# 50%    736271.239464     3.000000     0.000358   167.000000     5.500000
# 75%    736324.306692     3.333333     0.003670   266.000000    10.000000
# max    736405.000000     4.000000     2.000000   770.000000    46.000000
#
#           dislikes      txt_len
# count  2520.000000  2520.000000
# mean      1.261560    94.165367
# std       1.957477    80.893831
# min       0.000000     0.750000
# 25%       0.142857    43.475000
# 50%       0.692308    71.538949
# 75%       1.666667   117.462821
# max      33.000000   880.500000

# %% [markdown]
# # Saving cleaned dataset

# %%
df.to_csv('df_to_machine_learning.csv', index=False)
