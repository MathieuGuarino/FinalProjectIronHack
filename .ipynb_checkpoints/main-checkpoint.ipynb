# %% [markdown]
# # Data Analyze
# ## Daily Happiness & Employee Turnover

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
from sklearn import preprocessing
import numpy as np

# %%
churn = pd.read_csv('churn.csv')
commentInteractions = pd.read_csv('commentInteractions.csv')
votes = pd.read_csv('votes.csv')
comments_clean_anonimized = pd.read_csv('comments_clean_anonimized.csv')
# Out:
# /home/osboxes/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # 1.1 Last participation date of employees
#
# ## The lastParticipationExists.csv file contains information about the date of the last interaction of an employee with the app.
#
#     employee: An integer id that identifies an amployee inside a company. (negative = not in the company anymore)
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#     numVotes: Total number of happyness votes emited by the user.
#     lastParticipationDate: Date of the last interaction of the user with the app.
#     stillExists: Boolean that is True if the user is still registered in the app.

# %%
churn
# Out:
#       employee              companyAlias  numVotes  \
# 0          512  56aec740f1ef260003e307d6         4
# 1           -2  56aec740f1ef260003e307d6         0
# 2            2  56aec740f1ef260003e307d6        72
# 3          487  56aec740f1ef260003e307d6        14
# 4            3  56aec740f1ef260003e307d6        22
# ...        ...                       ...       ...
# 4842       857  58a728a0e75bda00042a3468         1
# 4843       858  58a728a0e75bda00042a3468         1
# 4844       859  58a728a0e75bda00042a3468         1
# 4845        17  573a0671b5ec330003add34a         7
# 4846        19  573a0671b5ec330003add34a         1
#
#               lastParticipationDate  stillExists
# 0      Thu Feb 23 12:48:04 CET 2017         True
# 1      Wed Jan 18 14:00:55 CET 2017        False
# 2      Fri Mar 17 01:00:00 CET 2017         True
# 3      Sat Nov 19 15:02:14 CET 2016        False
# 4      Thu Feb 16 01:00:00 CET 2017         True
# ...                             ...          ...
# 4842   Fri Mar 17 15:43:58 CET 2017         True
# 4843   Fri Mar 17 17:00:00 CET 2017         True
# 4844   Fri Mar 17 17:01:54 CET 2017         True
# 4845  Tue Jun 28 02:00:00 CEST 2016         True
# 4846  Mon Jul 04 19:02:03 CEST 2016         True
#
# [4847 rows x 5 columns]

# %%
# remove negative users, there seems to have no activities for these users
churn = churn[churn.employee > 0]
churn['uid'] = churn.employee.apply(str) + churn.companyAlias
churn = churn.drop_duplicates()
churn.sample()
# Out:
# <ipython-input-4-38d01ca9f760>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   churn['uid'] = churn.employee.apply(str) + churn.companyAlias
#       employee              companyAlias  numVotes  \
# 3207       164  574c5ade56b6300003009965        17
#
#              lastParticipationDate  stillExists                          uid
# 3207  Wed Dec 28 01:00:00 CET 2016         True  164574c5ade56b6300003009965

# %%
plt.figure(figsize=(20,8)) 
churn.numVotes.hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
churn.lastParticipationDate = pd.to_datetime(churn.lastParticipationDate)
#pd.to_datetime(churn.lastParticipationDate).apply(lambda x: x.toordinal())

# %%
churn_2016 = churn[(churn['lastParticipationDate'] >= '2016-01-01') & (churn['lastParticipationDate'] < '2017-01-01')]

# %%
churn.lastParticipationDate.describe()
# Out:
# <ipython-input-8-4780018c3794>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   churn.lastParticipationDate.describe()
# count                          4418
# unique                         1484
# top       2017-03-20 01:00:00+01:00
# freq                            478
# first     2014-06-07 02:00:00+02:00
# last      2017-03-20 21:25:54+01:00
# Name: lastParticipationDate, dtype: object

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4418 entries, 0 to 4846
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               4418 non-null   int64
#  1   companyAlias           4418 non-null   object
#  2   numVotes               4418 non-null   int64
#  3   lastParticipationDate  4418 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            4418 non-null   bool
#  5   uid                    4418 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 211.4+ KB

# %%
fig, ax = plt.subplots(figsize=(13,13))
sns.lineplot(data=churn_2016, x="lastParticipationDate", y="numVotes")
# Out:
# <AxesSubplot:xlabel='lastParticipationDate', ylabel='numVotes'>

# %%
sns.countplot(x="stillExists", data=churn)
# Out:
# <AxesSubplot:xlabel='stillExists', ylabel='count'>

# %%
employee_still_exists = churn[(churn.stillExists == True) & (churn.employee > 0)]
employee_still_exists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3673 entries, 0 to 4846
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               3673 non-null   int64
#  1   companyAlias           3673 non-null   object
#  2   numVotes               3673 non-null   int64
#  3   lastParticipationDate  3673 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            3673 non-null   bool
#  5   uid                    3673 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 175.8+ KB

# %%
employee_still_exists.numVotes.mean()
# Out:
# 52.253199019874764

# %%
employee_doesnot_exists = churn[(churn.stillExists == False) & (churn.employee > 0)]
employee_doesnot_exists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 3 to 4730
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               745 non-null    int64
#  1   companyAlias           745 non-null    object
#  2   numVotes               745 non-null    int64
#  3   lastParticipationDate  745 non-null    datetime64[ns, tzlocal()]
#  4   stillExists            745 non-null    bool
#  5   uid                    745 non-null    object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 35.6+ KB

# %%
employee_doesnot_exists.numVotes.mean()
# Out:
# 40.98523489932886

# %%
employee_doesnot_exists.numVotes.hist()
# Out:
# <AxesSubplot:>

# %%
employee_still_exists.numVotes.hist()
# Out:
# <AxesSubplot:>

# %%
to_transform = churn.groupby('companyAlias').mean().drop('employee', axis=1)
to_transform.head()
# Out:
#                            numVotes  stillExists
# companyAlias
# 5370af43e4b0cff95558c12a  28.285714     0.227679
# 53a2dd43e4b01cc02f1e9011  32.500000     0.916667
# 5474b9cde4b0bf7614b2c66f   4.600000     1.000000
# 54d43612e4b0f6a40755d93e  21.190476     0.666667
# 54e52607e4b01191dc064966  87.622222     0.507692

# %%
# à gérêr plus tard
x = to_transform[['numVotes']].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

# %%
#df['stillExists'] = churn.stillExists.astype(int)
df['stillExists'] = to_transform.stillExists.values

# %%
df['companyAlias'] = to_transform.reset_index().companyAlias

# %%
df.columns = ['numVotes','stillExists','companyAlias']

# %%
sns.scatterplot(data=df, x="numVotes", y="stillExists")
# Out:
# <AxesSubplot:xlabel='numVotes', ylabel='stillExists'>

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4418 entries, 0 to 4846
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               4418 non-null   int64
#  1   companyAlias           4418 non-null   object
#  2   numVotes               4418 non-null   int64
#  3   lastParticipationDate  4418 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            4418 non-null   bool
#  5   uid                    4418 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 371.4+ KB

# %%
churn.describe()
# Out:
#           employee     numVotes
# count  4418.000000  4418.000000
# mean    190.752603    50.353101
# std     202.581563    73.166365
# min       1.000000     0.000000
# 25%      49.000000     5.000000
# 50%     130.000000    19.000000
# 75%     247.000000    66.000000
# max     999.000000   740.000000

# %% [markdown]
# # 1.2 Employee Interactions
#
# ## The file commentInteractions.csv contains information about which employee liked or disliked a given comment.
#
#     employee: An integer id that identifies an amployee inside a company.
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#
#     commentId: A unique id for a given comment that allows us to relate it with the comments in anon_comments.csv.
#
#     liked: A boolean that is True if the employee liked the comment.
#     disliked: A boolean that is True if the employee disliked the comment.

# %%
commentInteractions
# Out:
#         employee              companyAlias liked disliked  \
# 0            307  56aec740f1ef260003e307d6  True    False
# 1             36  56aec740f1ef260003e307d6  True    False
# 2            276  56aec740f1ef260003e307d6  True    False
# 3             24  56aec740f1ef260003e307d6  True    False
# 4            382  56aec740f1ef260003e307d6  True    False
# ...          ...                       ...   ...      ...
# 336955       -49  58a728a0e75bda00042a3468  True    False
# 336956       232  58a728a0e75bda00042a3468  True    False
# 336957       -25  58a728a0e75bda00042a3468  True    False
# 336958        36  58a728a0e75bda00042a3468  True    False
# 336959       -47                   58a728a   NaN      NaN
#
#                        commentId
# 0       58d018d7e010990004e38070
# 1       58d018d7e010990004e38070
# 2       58d018d7e010990004e38070
# 3       58d018d7e010990004e38070
# 4       58d0179ae010990004e3806d
# ...                          ...
# 336955  58ad8adeb8242400048bf834
# 336956  58ad8adeb8242400048bf834
# 336957  58ad8adeb8242400048bf834
# 336958  58ad8adeb8242400048bf834
# 336959                       NaN
#
# [336960 rows x 5 columns]

# %%
commentInteractions = commentInteractions[commentInteractions.employee > 0]
commentInteractions['uid'] = commentInteractions.employee.apply(str) + commentInteractions.companyAlias
commentInteractions = commentInteractions.drop_duplicates()
# Out:
# <ipython-input-27-28dac2d79c45>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commentInteractions['uid'] = commentInteractions.employee.apply(str) + commentInteractions.companyAlias

# %%
commentInteractions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324471 entries, 0 to 336958
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   employee      324471 non-null  int64
#  1   companyAlias  324471 non-null  object
#  2   liked         324471 non-null  object
#  3   disliked      324471 non-null  object
#  4   commentId     324471 non-null  object
#  5   uid           324471 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 17.3+ MB

# %%
commentInteractions = commentInteractions.dropna() #we only have one na row

# %%
commentInteractions.liked.sum() / commentInteractions.shape[0]
# Out:
# 0.8436963549901224

# %%
commentInteractions.disliked.sum() / commentInteractions.shape[0]
# Out:
# 0.15630364500987762

# %%
commentInteractions.liked = commentInteractions.liked.astype(int)
commentInteractions.disliked = commentInteractions.disliked.astype(int)

# %%
commentInteractions_grouped = commentInteractions.groupby('companyAlias').mean().drop('employee', axis = 1).reset_index()

# %%
sorted_commentInteractions = commentInteractions_grouped.sort_values(by=['liked'])

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(data=commentInteractions_grouped, x='liked', y='companyAlias', legend=False)
# Out:
# <AxesSubplot:xlabel='liked', ylabel='companyAlias'>

# %%
fig, ax = plt.subplots(figsize=(13,13))
ax = sns.barplot(data=sorted_commentInteractions, x='liked', y='companyAlias')
#ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
commentInteractions.describe()
# Out:
#             employee          liked       disliked
# count  324471.000000  324471.000000  324471.000000
# mean      172.173411       0.843696       0.156304
# std       178.699301       0.363144       0.363144
# min         1.000000       0.000000       0.000000
# 25%        45.000000       1.000000       0.000000
# 50%       128.000000       1.000000       0.000000
# 75%       214.000000       1.000000       0.000000
# max       999.000000       1.000000       1.000000

# %%
total_interaction_by_user = commentInteractions.groupby('uid').sum().drop('employee', axis = 1)
total_interaction_by_user
# Out:
#                              liked  disliked
# uid
# 10053a2dd43e4b01cc02f1e9011     60        55
# 1005641f96713664c000332c8cd    191        90
# 10056aec740f1ef260003e307d6    288         2
# 10056e2a905e3b6fe0003e32855     11         0
# 10056fd2b64f41c670003f643c8      5         0
# ...                            ...       ...
# 9957bb2f0b3bae540003a8d453      33        20
# 9957dd2d6a4018d9000339ca43       1         0
# 99581b08041a0ef8000308aef6      31        33
# 99654e52607e4b01191dc064966     20         2
# 99954e52607e4b01191dc064966      1         1
#
# [3147 rows x 2 columns]

# %%
commentInteractions.sample()
# Out:
#        employee              companyAlias  liked  disliked  \
# 73007       147  574c423856b6300003009953      1         0
#
#                       commentId                          uid
# 73007  584164300176d500049f93d0  147574c423856b6300003009953

# %% [markdown]
# # 1.3 Happyness votes data
#
# ## The data regarding the votes of the app users is stored in votes.csv. This file containg 4 different columns:
#
#     employee: An integer id that identifies an amployee inside a company.
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#     voteDate: String representing the date a given vote was emited.
#     vote: The numeric value of the vote emited ranging from 1 to 4.

# %%
votes
# Out:
#         employee              companyAlias                       voteDate  \
# 0             31  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 1             33  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 2             79  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 3             94  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# 4             16  56aec740f1ef260003e307d6   Mon Feb 01 01:00:00 CET 2016
# ...          ...                       ...                            ...
# 221227        17  573a0671b5ec330003add34a  Fri Jun 03 02:00:00 CEST 2016
# 221228        17  573a0671b5ec330003add34a  Tue Jun 07 02:00:00 CEST 2016
# 221229        17  573a0671b5ec330003add34a  Mon Jun 13 02:00:00 CEST 2016
# 221230        17  573a0671b5ec330003add34a  Tue Jun 28 02:00:00 CEST 2016
# 221231        19  573a0671b5ec330003add34a  Mon Jul 04 02:00:00 CEST 2016
#
#         vote
# 0          4
# 1          4
# 2          4
# 3          4
# 4          2
# ...      ...
# 221227     3
# 221228     4
# 221229     4
# 221230     4
# 221231     4
#
# [221232 rows x 4 columns]

# %%
votes = votes[votes.employee > 0]
votes['uid'] = votes.employee.apply(str) + votes.companyAlias
votes = votes.drop_duplicates()

# %%
votes.head()
# Out:
#    employee              companyAlias                      voteDate  vote  \
# 0        31  56aec740f1ef260003e307d6  Mon Feb 01 01:00:00 CET 2016     4
# 1        33  56aec740f1ef260003e307d6  Mon Feb 01 01:00:00 CET 2016     4
# 2        79  56aec740f1ef260003e307d6  Mon Feb 01 01:00:00 CET 2016     4
# 3        94  56aec740f1ef260003e307d6  Mon Feb 01 01:00:00 CET 2016     4
# 4        16  56aec740f1ef260003e307d6  Mon Feb 01 01:00:00 CET 2016     2
#
#                           uid
# 0  3156aec740f1ef260003e307d6
# 1  3356aec740f1ef260003e307d6
# 2  7956aec740f1ef260003e307d6
# 3  9456aec740f1ef260003e307d6
# 4  1656aec740f1ef260003e307d6

# %%
# group to analyze date with unique employees and not duplicates
votes_grouped = votes.groupby(['employee','companyAlias']).mean()

# %%
votes_grouped.describe()
# Out:
#               vote
# count  4377.000000
# mean      2.945912
# std       0.651171
# min       1.000000
# 25%       2.640000
# 50%       3.000000
# 75%       3.333333
# max       4.000000

# %%
votes_by_company = votes_grouped.groupby('companyAlias').mean().reset_index().sort_values(by='vote')

# %%
fig, ax = plt.subplots(figsize=(13,13))
ax = sns.barplot(data=votes_by_company, y='companyAlias', x='vote')

# %% [markdown]
# # 1.4 Comments data
#
# ## It is possible to find data about the comments written in the app in the anon_comments.csv file, and it has the following structure:
#
#     employee: An integer id that identifies an amployee inside a company.
#     companyAlias: A hash id for a given company that uses the app. An employee can be uniquely identified with the tuple (employee,companyAlias).
#     commentDate: String representing the date a given comment was written.
#     commentId: A unique id for a given comment.
#     comment: Anonimized comment. It has the same length as the original comment.
#     likes: Number of likes that the comment received.
#     dislikes: Number of dislikes that the comment received.

# %%
comments_clean_anonimized
# Out:
#        employee              companyAlias                 commentId  \
# 0           307  56aec740f1ef260003e307d6  58d018d7e010990004e38070
# 1           382  56aec740f1ef260003e307d6  58d0179ae010990004e3806d
# 2           172  56aec740f1ef260003e307d6  58cff8cde010990004e37f6a
# 3           135  56aec740f1ef260003e307d6  58cfefeee010990004e37f60
# 4           225  56aec740f1ef260003e307d6  58cfd9b4e010990004e37f52
# ...         ...                       ...                       ...
# 82751       118  58a728a0e75bda00042a3468  58ae85a69fd38f00045eeee4
# 82752       -10  58a728a0e75bda00042a3468  58ae7fa19fd38f00045eeee2
# 82753        -8  58a728a0e75bda00042a3468  58adbfcbb8242400048bf8c1
# 82754        64  58a728a0e75bda00042a3468  58adba78b8242400048bf8b5
# 82755       361  58a728a0e75bda00042a3468  58adb214b8242400048bf8a6
#
#                                                      txt  likes  dislikes  \
# 0      **********************************************...    4.0       0.0
# 1                          *****************************    1.0       2.0
# 2                            ***************************    3.0       0.0
# 3                            ***************************    1.0       1.0
# 4                      *********************************    3.0       2.0
# ...                                                  ...    ...       ...
# 82751  **********************************************...    1.0       0.0
# 82752                                  *****************    2.0       0.0
# 82753                             **********************    5.0       0.0
# 82754                 **********************************    3.0       0.0
# 82755                                                NaN    NaN       NaN
#
#                         commentDate
# 0      Mon Mar 20 19:00:17 CET 2017
# 1      Mon Mar 20 18:55:16 CET 2017
# 2      Mon Mar 20 16:44:02 CET 2017
# 3      Mon Mar 20 16:06:08 CET 2017
# 4      Mon Mar 20 14:30:50 CET 2017
# ...                             ...
# 82751  Thu Feb 23 07:44:48 CET 2017
# 82752  Thu Feb 23 07:22:12 CET 2017
# 82753  Wed Feb 22 17:43:39 CET 2017
# 82754  Wed Feb 22 17:20:07 CET 2017
# 82755                           NaN
#
# [82756 rows x 7 columns]

# %%
comments_clean_anonimized = comments_clean_anonimized[comments_clean_anonimized.employee > 0]
comments_clean_anonimized['uid'] = comments_clean_anonimized.employee.apply(str) + comments_clean_anonimized.companyAlias
comments_clean_anonimized = comments_clean_anonimized.drop_duplicates()
# Out:
# <ipython-input-47-9a8c4f3f44b9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_clean_anonimized['uid'] = comments_clean_anonimized.employee.apply(str) + comments_clean_anonimized.companyAlias

# %%
comments_clean_anonimized['txt_len'] = comments_clean_anonimized.txt.str.len()

# %%
comments_clean_anonimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38994 entries, 0 to 82755
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   employee      38994 non-null  int64
#  1   companyAlias  38994 non-null  object
#  2   commentId     38994 non-null  object
#  3   txt           38892 non-null  object
#  4   likes         38993 non-null  float64
#  5   dislikes      38993 non-null  float64
#  6   commentDate   38993 non-null  object
#  7   uid           38994 non-null  object
#  8   txt_len       38892 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.0+ MB

# %%
comments_clean_anonimized.describe()
# Out:
#            employee         likes      dislikes       txt_len
# count  38994.000000  38993.000000  38993.000000  38892.000000
# mean     150.956634      7.002488      1.297977    102.405379
# std      157.279482      7.773628      2.748012    202.858059
# min        1.000000      0.000000      0.000000      1.000000
# 25%       38.000000      2.000000      0.000000     28.000000
# 50%      112.000000      4.000000      0.000000     57.000000
# 75%      207.000000     10.000000      1.000000    119.000000
# max      999.000000     86.000000     53.000000  29057.000000

# %%
comments_clean_anonimized.likes.sum()
# Out:
# 273048.0

# %%
comments_clean_anonimized.dislikes.sum()
# Out:
# 50612.0

# %%
comments_grouped = comments_clean_anonimized.groupby('companyAlias').mean().drop('employee', axis = 1).sort_values(by=['likes'], ascending = False)
comments_grouped.head()
# Out:
#                               likes  dislikes     txt_len
# companyAlias
# 5742d699f839a10003a407d2  14.238628  1.112975  198.979065
# 5641f96713664c000332c8cd  12.640990  2.844197  140.652933
# 574c5ade56b6300003009965  10.133936  1.902629  126.624486
# 58a728a0e75bda00042a3468  10.071766  2.841360   98.922568
# 57d956302a040a00036a8905   9.160800  0.902400  105.902400

# %%
sns.regplot(data=comments_grouped, x="txt_len", y="likes",  scatter_kws={"s": 80}, ci=None, robust=True)
# Out:
# <AxesSubplot:xlabel='txt_len', ylabel='likes'>

# %%
sns.regplot(data=comments_grouped, x="txt_len", y="dislikes", robust= True, ci=None)
# Out:
# <AxesSubplot:xlabel='txt_len', ylabel='dislikes'>

# %% [markdown]
# #  Datasets merger

# %%
churn.sample(2)
# numVotes is not up to date !!!
# Out:
#       employee              companyAlias  numVotes     lastParticipationDate  \
# 2741         1  58b471b384db3200044dd1b9        11 2017-03-20 01:00:00+01:00
# 3826       142  57ac8b23be7fe30003e656d0        50 2017-03-17 01:00:00+01:00
#
#       stillExists                          uid
# 2741         True    158b471b384db3200044dd1b9
# 3826         True  14257ac8b23be7fe30003e656d0

# %%
churn.numVotes.sum()
# Out:
# 222460

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4418 entries, 0 to 4846
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee               4418 non-null   int64
#  1   companyAlias           4418 non-null   object
#  2   numVotes               4418 non-null   int64
#  3   lastParticipationDate  4418 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            4418 non-null   bool
#  5   uid                    4418 non-null   object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(2), object(2)
# memory usage: 371.4+ KB

# %%
total_interaction_by_user.sample(2)
# Out:
#                              liked  disliked
# uid
# 11554e52607e4b01191dc064966     75         5
# 52574c5ade56b6300003009965      53         7

# %%
total_interaction_by_user.head()
# Out:
#                              liked  disliked
# uid
# 10053a2dd43e4b01cc02f1e9011     60        55
# 1005641f96713664c000332c8cd    191        90
# 10056aec740f1ef260003e307d6    288         2
# 10056e2a905e3b6fe0003e32855     11         0
# 10056fd2b64f41c670003f643c8      5         0

# %%
total_interaction_by_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3147 entries, 10053a2dd43e4b01cc02f1e9011 to 99954e52607e4b01191dc064966
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   liked     3147 non-null   int64
#  1   disliked  3147 non-null   int64
# dtypes: int64(2)
# memory usage: 73.8+ KB

# %%
votes.sample(2)
# Out:
#        employee              companyAlias                       voteDate  \
# 80229       492  54e52607e4b01191dc064966  Wed Apr 06 02:00:00 CEST 2016
# 67983       174  54e52607e4b01191dc064966  Fri Sep 11 02:00:00 CEST 2015
#
#        vote                          uid
# 80229     4  49254e52607e4b01191dc064966
# 67983     1  17454e52607e4b01191dc064966

# %%
votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221145 entries, 0 to 221231
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   employee      221145 non-null  int64
#  1   companyAlias  221145 non-null  object
#  2   voteDate      221145 non-null  object
#  3   vote          221145 non-null  int64
#  4   uid           221145 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 10.1+ MB

# %%
comments_clean_anonimized.sample(2)
# Out:
#        employee              companyAlias                 commentId  \
# 81181       324  58a728a0e75bda00042a3468  58b92cef46b59c00044ee4df
# 25835        48  57908a2622881200033b34d7  58a5a7b684356a0004bb499b
#
#                                  txt  likes  dislikes  \
# 81181  *****************************   17.0       2.0
# 25835                 **************    0.0       0.0
#
#                         commentDate                          uid  txt_len
# 81181  Fri Mar 03 09:44:18 CET 2017  32458a728a0e75bda00042a3468     29.0
# 25835  Thu Feb 16 14:22:33 CET 2017   4857908a2622881200033b34d7     14.0

# %%
comments_clean_anonimized[comments_clean_anonimized.uid == '10053a2dd43e4b01cc02f1e9011']
# Out:
#        employee              companyAlias                 commentId  \
# 63457       100  53a2dd43e4b01cc02f1e9011  57e97335bad95d00030858c3
# 63527       100  53a2dd43e4b01cc02f1e9011  57c97219a550ce0003eb5e89
# 63803       100  53a2dd43e4b01cc02f1e9011  57759786f907d700031600c3
# 63848       100  53a2dd43e4b01cc02f1e9011  576c27f6c7cda30003363ce5
# 63884       100  53a2dd43e4b01cc02f1e9011  5765783a44bef90003294c13
# 63924       100  53a2dd43e4b01cc02f1e9011  57603c51fdfb340003a74c4b
# 64059       100  53a2dd43e4b01cc02f1e9011  574b5a16b62d4600039c9148
# 64087       100  53a2dd43e4b01cc02f1e9011  5746e87755015a00032e11fa
# 64162       100  53a2dd43e4b01cc02f1e9011  573ce28a44d85900031c3b7d
# 64175       100  53a2dd43e4b01cc02f1e9011  573b8b0a8a14ae0003ac74c0
# 64474       100  53a2dd43e4b01cc02f1e9011  571d344462947b00037635b0
# 64490       100  53a2dd43e4b01cc02f1e9011  571b846deaac4e00034511fd
# 64581       100  53a2dd43e4b01cc02f1e9011  5716976a429f530003ee60b2
# 64746       100  53a2dd43e4b01cc02f1e9011  570c1d7a78d7b0000320afdb
# 64831       100  53a2dd43e4b01cc02f1e9011  57067af7e0039c00038681a9
# 64846       100  53a2dd43e4b01cc02f1e9011  5705965403498b0003e65553
# 65079       100  53a2dd43e4b01cc02f1e9011  56f9674427be6b0003bedb19
# 65252       100  53a2dd43e4b01cc02f1e9011  56f05d08b2961a0003c73b41
#
#                                                      txt  likes  dislikes  \
# 63457  **********************************************...    1.0       2.0
# 63527  **********************************************...    2.0       2.0
# 63803  **********************************************...    2.0       4.0
# 63848                 **********************************    1.0       2.0
# 63884  **********************************************...    1.0       3.0
# 63924  **********************************************...    1.0       1.0
# 64059  **********************************************...    1.0       3.0
# 64087  **********************************************...    3.0       5.0
# 64162  **********************************************...    2.0       5.0
# 64175       ********************************************    1.0       2.0
# 64474                           ************************    0.0       0.0
# 64490  **********************************************...    1.0       2.0
# 64581  **********************************************...    8.0       0.0
# 64746  **********************************************...    6.0       1.0
# 64831  **********************************************...    1.0       4.0
# 64846  **********************************************...    4.0       1.0
# 65079  **********************************************...   12.0       3.0
# 65252  **********************************************...    5.0       2.0
#
#                          commentDate                          uid  txt_len
# 63457  Mon Sep 26 20:17:07 CEST 2016  10053a2dd43e4b01cc02f1e9011    522.0
# 63527  Fri Sep 02 14:32:22 CEST 2016  10053a2dd43e4b01cc02f1e9011     81.0
# 63803  Fri Jul 01 00:02:33 CEST 2016  10053a2dd43e4b01cc02f1e9011    201.0
# 63848  Thu Jun 23 20:17:36 CEST 2016  10053a2dd43e4b01cc02f1e9011     34.0
# 63884  Sat Jun 18 18:31:16 CEST 2016  10053a2dd43e4b01cc02f1e9011    252.0
# 63924  Tue Jun 14 19:15:19 CEST 2016  10053a2dd43e4b01cc02f1e9011    239.0
# 64059  Sun May 29 23:02:31 CEST 2016  10053a2dd43e4b01cc02f1e9011    157.0
# 64087  Thu May 26 14:10:13 CEST 2016  10053a2dd43e4b01cc02f1e9011    217.0
# 64162  Wed May 18 23:39:38 CEST 2016  10053a2dd43e4b01cc02f1e9011    142.0
# 64175  Tue May 17 23:19:24 CEST 2016  10053a2dd43e4b01cc02f1e9011     44.0
# 64474  Sun Apr 24 23:01:34 CEST 2016  10053a2dd43e4b01cc02f1e9011     24.0
# 64490  Sat Apr 23 16:14:34 CEST 2016  10053a2dd43e4b01cc02f1e9011    114.0
# 64581  Tue Apr 19 22:36:07 CEST 2016  10053a2dd43e4b01cc02f1e9011    272.0
# 64746  Mon Apr 11 23:56:08 CEST 2016  10053a2dd43e4b01cc02f1e9011    169.0
# 64831  Thu Apr 07 17:21:25 CEST 2016  10053a2dd43e4b01cc02f1e9011     89.0
# 64846  Thu Apr 07 01:05:55 CEST 2016  10053a2dd43e4b01cc02f1e9011    191.0
# 65079  Mon Mar 28 19:17:54 CEST 2016  10053a2dd43e4b01cc02f1e9011    410.0
# 65252   Mon Mar 21 21:43:50 CET 2016  10053a2dd43e4b01cc02f1e9011    203.0

# %%
comments_clean_anonimized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38994 entries, 0 to 82755
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   employee      38994 non-null  int64
#  1   companyAlias  38994 non-null  object
#  2   commentId     38994 non-null  object
#  3   txt           38892 non-null  object
#  4   likes         38993 non-null  float64
#  5   dislikes      38993 non-null  float64
#  6   commentDate   38993 non-null  object
#  7   uid           38994 non-null  object
#  8   txt_len       38892 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.0+ MB

# %%
df = comments_clean_anonimized.drop(['employee','companyAlias','txt'], axis=1).merge(total_interaction_by_user, left_on='uid', right_on='uid')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37944 entries, 0 to 37943
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   commentId    37944 non-null  object
#  1   likes        37943 non-null  float64
#  2   dislikes     37943 non-null  float64
#  3   commentDate  37943 non-null  object
#  4   uid          37944 non-null  object
#  5   txt_len      37843 non-null  float64
#  6   liked        37944 non-null  int64
#  7   disliked     37944 non-null  int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 2.6+ MB

# %%
df2 = votes.drop(['employee','companyAlias'], axis=1).groupby('uid').mean().merge(churn.drop(['employee','companyAlias'], axis=1), left_on='uid', right_on='uid')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4418 entries, 0 to 4417
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   uid                    4418 non-null   object
#  1   vote                   4418 non-null   float64
#  2   numVotes               4418 non-null   int64
#  3   lastParticipationDate  4418 non-null   datetime64[ns, tzlocal()]
#  4   stillExists            4418 non-null   bool
# dtypes: bool(1), datetime64[ns, tzlocal()](1), float64(1), int64(1), object(1)
# memory usage: 176.9+ KB

# %%
df3 = df.merge(df2, left_on='uid', right_on='uid')
df3
# Out:
#                       commentId  likes  dislikes  \
# 0      58d018d7e010990004e38070    4.0       0.0
# 1      58c913dfbd760e00043f1695    8.0       1.0
# 2      58c736e732f72a00046f5614    5.0       0.0
# 3      58c53f19307b1e0004ad41af    8.0       0.0
# 4      58c3ccf161ca670004c032fb    5.0       0.0
# ...                         ...    ...       ...
# 38583  58ae85a69fd38f00045eeee4    1.0       0.0
# 38584  58ad8f82b8242400048bf840    6.0       1.0
# 38585  58ad905ab8242400048bf843   46.0       1.0
# 38586  58ad8a0db8242400048bf832    6.0       0.0
# 38587  58ad870bb8242400048bf82e   15.0      24.0
#
#                         commentDate                          uid  txt_len  \
# 0      Mon Mar 20 19:00:17 CET 2017  30756aec740f1ef260003e307d6     62.0
# 1      Wed Mar 15 11:12:39 CET 2017  30756aec740f1ef260003e307d6     87.0
# 2      Tue Mar 14 01:18:23 CET 2017  30756aec740f1ef260003e307d6     32.0
# 3      Sun Mar 12 13:28:34 CET 2017  30756aec740f1ef260003e307d6     76.0
# 4      Sat Mar 11 11:09:36 CET 2017  30756aec740f1ef260003e307d6     22.0
# ...                             ...                          ...      ...
# 38583  Thu Feb 23 07:44:48 CET 2017  11858a728a0e75bda00042a3468    143.0
# 38584  Wed Feb 22 14:14:43 CET 2017  11858a728a0e75bda00042a3468    139.0
# 38585  Wed Feb 22 14:20:27 CET 2017  47058a728a0e75bda00042a3468     31.0
# 38586  Wed Feb 22 13:54:16 CET 2017  48558a728a0e75bda00042a3468     41.0
# 38587  Wed Feb 22 13:35:22 CET 2017  26658a728a0e75bda00042a3468    224.0
#
#        liked  disliked      vote  numVotes     lastParticipationDate  \
# 0        305        24  3.487179        78 2017-03-20 19:00:17+01:00
# 1        305        24  3.487179        78 2017-03-20 19:00:17+01:00
# 2        305        24  3.487179        78 2017-03-20 19:00:17+01:00
# 3        305        24  3.487179        78 2017-03-20 19:00:17+01:00
# 4        305        24  3.487179        78 2017-03-20 19:00:17+01:00
# ...      ...       ...       ...       ...                       ...
# 38583      1         0  2.500000         2 2017-02-23 07:44:48+01:00
# 38584      1         0  2.500000         2 2017-02-23 07:44:48+01:00
# 38585      1         0  2.000000         1 2017-02-22 16:16:42+01:00
# 38586     14         3  3.000000        14 2017-03-14 01:00:00+01:00
# 38587     18         1  2.333333         3 2017-03-01 15:41:12+01:00
#
#        stillExists
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ...            ...
# 38583         True
# 38584         True
# 38585         True
# 38586         True
# 38587         True
#
# [38588 rows x 12 columns]

# %%
comments_clean_anonimized[comments_clean_anonimized.commentId == '58ad905ab8242400048bf843']
# Out:
#        employee              companyAlias                 commentId  \
# 81598       470  58a728a0e75bda00042a3468  58ad905ab8242400048bf843
#
#                                    txt  likes  dislikes  \
# 81598  *******************************   46.0       1.0
#
#                         commentDate                          uid  txt_len
# 81598  Wed Feb 22 14:20:27 CET 2017  47058a728a0e75bda00042a3468     31.0

# %%
df3[df3.commentId == '58d018d7e010990004e38070']
# Out:
#                   commentId  likes  dislikes                   commentDate  \
# 0  58d018d7e010990004e38070    4.0       0.0  Mon Mar 20 19:00:17 CET 2017
#
#                            uid  txt_len  liked  disliked      vote  numVotes  \
# 0  30756aec740f1ef260003e307d6     62.0    305        24  3.487179        78
#
#       lastParticipationDate  stillExists
# 0 2017-03-20 19:00:17+01:00         True

# %%
churn.sample()
# Out:
#       employee              companyAlias  numVotes     lastParticipationDate  \
# 3113        47  574c5ade56b6300003009965        18 2017-01-26 01:00:00+01:00
#
#       stillExists                         uid
# 3113         True  47574c5ade56b6300003009965

# %% [markdown]
# # Join data by uid to look if stillExists ...

# %% [markdown]
# # Saving cleaned dataset

# %%
votes_ml.to_csv('clean_data/votes_ml.csv')
comments_ml.to_csv('clean_data/comments_ml.csv')
inters_ml.to_csv('clean_data/interactions_ml.csv')
target_happy.to_csv('clean_data/target_ml.csv')
